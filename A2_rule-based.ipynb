# %% [markdown]
# # Sample Code

# %% [markdown]
# ## 基礎建設

# %%
import pandas as pd
import gzip, json

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %% [markdown]
# ## 載入資料

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/All_Beauty.csv
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_All_Beauty.json.gz
# Out:
# --2021-12-26 12:19:55--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/All_Beauty.csv
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15499476 (15M) [application/octet-stream]
# Saving to: ‘All_Beauty.csv’
#
# All_Beauty.csv      100%[===================>]  14.78M  40.7MB/s    in 0.4s
#
# 2021-12-26 12:19:56 (40.7 MB/s) - ‘All_Beauty.csv’ saved [15499476/15499476]
#
# --2021-12-26 12:19:56--  http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_All_Beauty.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10329961 (9.9M) [application/octet-stream]
# Saving to: ‘meta_All_Beauty.json.gz’
#
# meta_All_Beauty.jso 100%[===================>]   9.85M  32.1MB/s    in 0.3s
#
# 2021-12-26 12:19:56 (32.1 MB/s) - ‘meta_All_Beauty.json.gz’ saved [10329961/10329961]

# %%
metadata = getDF('/content/meta_All_Beauty.json.gz')
ratings = pd.read_csv('/content/All_Beauty.csv', names=['asin', 'reviewerID', 'overall', 'unixReviewTime'], header=None)

# %%
metadata.head()
# Out:
#   category  ...                                    imageURLHighRes
# 0       []  ...                                                 []
# 1       []  ...                                                 []
# 2       []  ...                                                 []
# 3       []  ...  [https://images-na.ssl-images-amazon.com/image...
# 4       []  ...  [https://images-na.ssl-images-amazon.com/image...
#
# [5 rows x 19 columns]

# %%
ratings.head()
# Out:
#          asin      reviewerID  overall  unixReviewTime
# 0  0143026860  A1V6B6TNIC10QE      1.0      1424304000
# 1  0143026860  A2F5GHSXFQ0W6J      4.0      1418860800
# 2  0143026860  A1572GUYS7DGSR      4.0      1407628800
# 3  0143026860   A1PSGLFK1NSVO      5.0      1362960000
# 4  0143026860   A6IKXKZMTKGSC      5.0      1324771200

# %% [markdown]
# ## 資料整理

# %%
ratings['DATE'] = pd.to_datetime(ratings['unixReviewTime'], unit='s')

# %% [markdown]
# ## 資料切分

# %%
ratings_trainings = ratings[
    (ratings['DATE'] < '2018-09-01')
]
ratings_testings = ratings[
    (ratings['DATE'] >= '2018-09-01') & 
    (ratings['DATE'] <= '2018-09-30')
]
ratings_testings_by_user = ratings_testings.groupby('reviewerID').agg(list).reset_index()[['reviewerID', 'asin']].to_dict('records')
ratings_testings_by_user = { rating['reviewerID']: rating['asin'] for rating in ratings_testings_by_user }
users = list(ratings_testings_by_user.keys())

# %% [markdown]
# ## 產生推薦

# %%
def recommender(training_data, users=[], k=10):
    '''
    * training_data: dataframe 輸入的訓練資料集（2018-09-01 以前資料）
    * users: [] 需要被推薦的使用者
    * k: int 每個使用者需要推薦的商品數
    * recommendations: dict
      {
          使用者一： [推薦商品一, 推薦商品二, ...],
          使用者二： [...], ...
      }
    '''
    recommendations = {}
    '''
    random-based
    '''
    ratings_trainings = training_data
    recommendations = {user: ratings_trainings['asin'].sample(n=k).tolist() for user in users}
    
    return recommendations


ratings_by_user = recommender(ratings_trainings, users)
ratings_by_user
# Out:
# {'A100XQFWKQ30O2': ['B008U1Q4DI',
#   'B000WYJTZG',
#   'B004LUQRJI',
#   'B01DGWYQCG',
#   'B017HU76I4',
#   'B00RNKER4U',
#   'B0044LFHVI',
#   'B00W259T7G',
#   'B00OXJZ73E',
#   'B002N5MI3W'],
#  'A103T1QOGFCSEH': ['B01GW09XRW',
#   'B00SLNMU74',
#   'B0001HYKC6',
#   'B01G53UOME',
#   'B004BD9152',
#   'B0006M56BK',
#   'B000GZJIVQ',
#   'B00005JS5C',
#   'B005IHT94S',
#   'B000NY66DS'],
#  'A106UKKSJ2KXPF': ['B00VF344X0',
#   'B00070D21W',
#   'B00YQBYO1K',
#   'B00ZP3COZ6',
#   'B01775OUCY',
#   'B00Y09GR6S',
#   'B0002PU864',
#   'B000H6A02A',
#   'B010DM018K',
#   'B00N9KWECK'],
#  'A10A7GV4D5A11V': ['B008U1Q4DI',
#   'B00UXAE5Q2',
#   'B00IYSQIPG',
#   'B000FOI48G',
#   'B006GDB518',
#   'B01ANT46G6',
#   'B00J9MJDFS',
#   'B0091OCA86',
#   'B01EMTIJES',
#   'B001QY8QXM'],
#  'A1119JJ37ZLB8R': ['B0000530HU',
#   'B00BMVV3MK',
#   'B001QY8QXM',
#   'B00GLJDO4S',
#   'B00LX6FJ6K',
#   '1620213982',
#   'B000FDDK5E',
#   'B00BMVV3MK',
#   'B007OLPX3M',
#   'B01A8DBE3A'],
#  'A113UOOLBSZN52': ['B000GLRREU',
#   'B011M4QBX2',
#   'B01AQDXOL2',
#   'B018J05XSQ',
#   'B016BYHY4I',
#   'B000050FDY',
#   'B00Y98VTTK',
#   'B014GONBJW',
#   'B011DL6I6Y',
#   'B013XKHA4M'],
#  'A12M4U7WK4ALCR': ['B00L0JYAZG',
#   'B00QF41O1E',
#   'B00CHO8VTE',
#   'B00RFE2W5A',
#   'B001OHV1H4',
#   'B000FOI48G',
#   'B0010ZBORW',
#   'B007UHY8IG',
#   'B01612WMH4',
#   'B013W4YFTW'],
#  'A12T8YTW6VWT7S': ['B007JUIBMI',
#   'B000GLRREU',
#   'B003U80TAU',
#   'B00BHLQGMC',
#   'B011JG1K3E',
#   'B004RRTLQ6',
#   'B001OHV1H4',
#   'B001F51RBU',
#   'B00VF344X0',
#   'B01DGWYQCG'],
#  'A1364JXGKB46MM': ['B01AS2F1US',
#   'B000B658RI',
#   'B0017TZD7S',
#   'B001AJ6YS2',
#   'B007FAOQF8',
#   'B000GX1N52',
#   'B000Q46HBQ',
#   'B009DG6FTM',
#   'B00L1I1VMG',
#   'B00BY8AGHE'],
#  'A137DALOQFKBTI': ['B01GFR0W2W',
#   'B00PQVK0GC',
#   'B008U1Q4DI',
#   'B00N9QUG0Q',
#   'B01AI9GH68',
#   'B00NE5ZHB0',
#   'B01H71NG0K',
#   'B00016WULK',
#   'B014VYPWNU',
#   'B01F9A4FYM'],
#  'A13FEZ3WV7S2EY': ['B00H78MSP8',
#   'B0154FJHYK',
#   'B006IB5T4W',
#   'B004GSX0ZY',
#   'B013TXDDJY',
#   'B01BVGC5I6',
#   'B0083UAUJ0',
#   'B01G286XBS',
#   'B001441XFM',
#   'B01G62SJQC'],
#  'A13IV4I1B0RXMG': ['1620213982',
#   'B005IHT94S',
#   'B00GW58YC8',
#   'B00LSCERXU',
#   'B006TAHH3I',
#   'B00W259T7G',
#   'B000VV1YOY',
#   'B00CCG7UZS',
#   'B001P2NRPC',
#   'B00W259T7G'],
#  'A13JU88JAHN72I': ['B018PDF0JY',
#   'B00X3Q81SQ',
#   'B00OXDWFG2',
#   'B01185LNOW',
#   'B01DKQAXC0',
#   'B00IAA4ULM',
#   'B01GS5NLH4',
#   'B00EF1QRMU',
#   'B00YI0XFUU',
#   'B00HQNLT7C'],
#  'A13K55R6VH1OOD': ['B000FOI48G',
#   'B008O0ZTPO',
#   'B000UYIQYI',
#   'B01F1MP69Q',
#   'B017CHORY8',
#   'B00BKU65QW',
#   'B00P85Q3JY',
#   'B004DPDSHU',
#   'B001AMRQ2W',
#   'B00005JS5C'],
#  'A13P7VFU075A': ['B00U1VSN98',
#   'B016YROO36',
#   'B000FEF1V4',
#   'B00KPH8N8E',
#   'B001AJ6YS2',
#   'B00JIESMR2',
#   'B013GX0LT2',
#   'B01FUOKTDI',
#   'B00GE5GLQC',
#   'B000NJJFBI'],
#  'A13SWYE4QLB6NG': ['B0051S94NA',
#   'B000V5Z4J6',
#   'B000GLRREU',
#   'B00H1AWB6S',
#   'B004BC62MI',
#   'B00IAA77Y4',
#   'B001R72IBE',
#   'B005K1P6G2',
#   'B0167G6VFI',
#   'B000PKKAFK'],
#  'A13ZTQ0Q4ATA41': ['B005MXC7RO',
#   'B00KHYHOSK',
#   'B00O1DY34G',
#   'B009ON95KU',
#   'B0012Y0ZG2',
#   'B00HGDKN8S',
#   'B0001HYKBM',
#   'B004VGIA60',
#   'B00ATV35SY',
#   '3317005939'],
#  'A142EDN04OD62U': ['B000S17FUO',
#   'B00C6NZH3E',
#   'B01C3FZLXA',
#   'B00N57PFYG',
#   'B004V439HC',
#   'B000GCRWE4',
#   'B000NSV6R0',
#   'B00NJ270ZY',
#   'B006IB5T4W',
#   'B008U1Q4DI'],
#  'A142I22FIC8MZK': ['B00ESZLEXK',
#   'B001QY8QXM',
#   'B00MNAE3KS',
#   'B00JYXZ0FO',
#   'B00JVU3K9I',
#   'B00VF344X0',
#   'B01CNLMWE0',
#   'B004ETIWL2',
#   'B001CUU9KI',
#   'B004MBJL58'],
#  'A14834QTII5TLT': ['B01GQ12URM',
#   'B000USALAQ',
#   'B000GLRREU',
#   'B0054H0NZ6',
#   'B00CCG7UZS',
#   'B004BD9152',
#   'B000FEGUIW',
#   'B00TPFWG76',
#   'B0173SQ1LI',
#   'B013TXDDJY'],
#  'A14A447VPACTBC': ['B00028LYO6',
#   'B00UNI2O4O',
#   'B0000C4KJX',
#   'B00C6NZH3E',
#   'B000GCSYHI',
#   'B00M3JZURE',
#   'B00KW7OMQY',
#   'B0091OCA86',
#   'B001QY8QXM',
#   'B000MOH552'],
#  'A14AP6MN5XO6LB': ['B006WYJM8Y',
#   'B002BTFQAW',
#   'B00LJ7JVM6',
#   'B019809F9Y',
#   'B00S8LDM1M',
#   'B004XXKIGQ',
#   'B018IWXF44',
#   'B00N2WQ2IW',
#   'B01BNEYGQU',
#   'B00TKJET7W'],
#  'A14CLF25IX25US': ['B00011QUDE',
#   'B015N6GYR8',
#   'B016QSRYR6',
#   'B01GCE7OO2',
#   'B0010ZBORW',
#   'B005D78YSU',
#   'B01DKQAXC0',
#   'B01DYU7SNE',
#   'B005HRT0U2',
#   'B01EFSI81K'],
#  'A14LYXC3HTBAHI': ['B00L62HMQG',
#   'B01ENWUSM0',
#   'B00WWP5FHO',
#   'B000PARERW',
#   'B000NR6F68',
#   'B0189CM3U0',
#   'B015Q98HPO',
#   'B00GNSILNQ',
#   'B000FI4S1E',
#   'B00J3G958K'],
#  'A14VUW4KZ34EOE': ['B000WYJTZG',
#   'B00G5R31A8',
#   'B00QAYMOY0',
#   'B00O5B7RCE',
#   'B00V2QVO74',
#   'B001CUU9KI',
#   'B01F7Z1EC0',
#   'B01AAVIO38',
#   'B00CCG7UZS',
#   'B0119N4G9C'],
#  'A14Y32P26G9YL': ['B000GLRREU',
#   'B00ARM4Q7O',
#   'B01FU1R79A',
#   'B004A7NXG2',
#   'B00MGXI0R4',
#   'B01B178A4S',
#   'B00NT0AR7E',
#   'B00D3M0CRS',
#   'B01A9MZLS4',
#   'B00MK92IJ0'],
#  'A157T25PBS7MX4': ['B001OHV1H4',
#   'B0017DQ0U8',
#   'B01E1KJWQC',
#   'B003983HRI',
#   'B012Z7IHHI',
#   'B00NE5Q9JO',
#   'B00VF344X0',
#   'B01ENL20AE',
#   'B00517W5LY',
#   'B00WR5RNUQ'],
#  'A15HZDSERD85C8': ['B00016WU6A',
#   'B01DKQAXC0',
#   'B0028ZO2Q8',
#   'B005FYHC9S',
#   'B000GGKPQM',
#   'B01DKQAXC0',
#   'B0052F21BY',
#   'B0049UKUYS',
#   'B015Y8LQN2',
#   'B01BZV6VVY'],
#  'A15JJ8J1FGADIX': ['B00IU5EDKK',
#   'B00CCNT72U',
#   'B005NCIJV2',
#   'B01HBJBHG8',
#   'B007K6LID0',
#   'B000A2LRBY',
#   'B015YEZ7Z4',
#   'B01B57QJHY',
#   'B01B7ADZEO',
#   'B002CMUHDY'],
#  'A15ZCL70JXXH89': ['B009GIND24',
#   'B00LIX0YPE',
#   'B00NW5C1H0',
#   'B00LEBK180',
#   'B015N6GYR8',
#   'B0086LC16Q',
#   'B00QX9PXAO',
#   'B001QY8QXM',
#   'B01DKQAXC0',
#   'B01B54XW54'],
#  'A1617KN2IAWZ6J': ['B0013YXQ58',
#   'B00J2AJ3U2',
#   'B00AM3YG2I',
#   'B01DVRHBZA',
#   'B0009VCUWG',
#   'B000FOI48G',
#   'B0002PU864',
#   'B003983HRI',
#   'B00070D21W',
#   'B00GW58YC8'],
#  'A16E0O88262HKA': ['B0052YPJ7S',
#   'B000J1HR6U',
#   'B00NT0AR7E',
#   'B00C6CCD8C',
#   'B00U1NREHI',
#   'B00C8HC1HI',
#   '1620213982',
#   'B00MGAJ5GM',
#   'B0181KNXPE',
#   'B001P5HCKK'],
#  'A16NSZ58PTVIYF': ['B000GG7NU8',
#   'B00H86AHHK',
#   'B01DKQAXC0',
#   'B00SQ3S6TA',
#   'B00AH5QVZG',
#   'B007RENB6M',
#   'B00YO55LJC',
#   'B002OXSKF8',
#   'B00152RCQ2',
#   'B00MYM816W'],
#  'A16UGDXRTDLJG5': ['B0014AX89K',
#   'B0016BFK2U',
#   'B00J2R8BP8',
#   'B005UDGJ0C',
#   'B01A87HI90',
#   '1620213982',
#   'B001BROT1M',
#   'B0010DMNFQ',
#   'B00DUQUYNO',
#   'B001AMRQ2W'],
#  'A16X9HR3UFQQXY': ['B01GR3IYJW',
#   'B015Q437KE',
#   'B000EA8VSE',
#   'B01DVGC6C4',
#   'B00MFFWYN4',
#   'B00B1MTN2M',
#   'B000GCOIMI',
#   'B000FEF1V4',
#   'B000GLRREU',
#   'B00A6F1486'],
#  'A16Y7V1CZCWKFV': ['1620213982',
#   'B00JVU3K9I',
#   'B000WYJTZG',
#   'B00567UTKI',
#   'B000FOI48G',
#   'B00EORBS92',
#   'B00ATV35SY',
#   'B000XV745A',
#   'B0078PJ59W',
#   'B01AHSUT8M'],
#  'A174YOBOSW9WDN': ['B01CEBVRMW',
#   'B0195R1FT8',
#   'B0012Y0ZG2',
#   'B006SJR88Y',
#   'B001AMRQ2W',
#   'B00CBY9F7C',
#   'B00LW9E99G',
#   'B001QY8QXM',
#   'B00LH4KI7I',
#   'B00B1PO68U'],
#  'A1786SKRAJXH86': ['B017JSZKGY',
#   'B00QEABAIG',
#   'B000YB70PS',
#   'B000XV745A',
#   'B001UC6E2K',
#   'B00M6SKC0M',
#   'B004A7NXG2',
#   'B01APHE300',
#   'B000209JS2',
#   'B001QY8QXM'],
#  'A17K2BUZ20WD2': ['B00NX9A140',
#   'B001FB5LV6',
#   'B001V9FPHM',
#   'B00G22ETV6',
#   'B0042TNAV6',
#   'B00M7CUI8S',
#   'B000GLRREU',
#   'B00CV1ZLCI',
#   'B00MQJ8ELU',
#   'B008U1Q4DI'],
#  'A17LYRFV645L0V': ['B00MSZNAWK',
#   'B000GLRREU',
#   'B000BJ1CGQ',
#   'B00GHJOM2U',
#   'B00BJ87GYK',
#   'B00HJA9GPY',
#   'B00OTGVR5I',
#   'B00XDB3QTA',
#   'B000GLRREU',
#   'B00D3OX3EU'],
#  'A18LNGVXDZBTUR': ['B01CH80FEI',
#   'B009PIJV1W',
#   'B01B6YTFRC',
#   'B01GGNW5EI',
#   'B01C71445Q',
#   'B00QAU4GKE',
#   'B0185DYUCM',
#   'B014TKIBBQ',
#   'B0043ZJR9S',
#   'B010XPUY4S'],
#  'A19503XX7GU6J2': ['B000XV745A',
#   'B0012Y0ZG2',
#   'B001AJD0UM',
#   'B00BPYXLEM',
#   'B00H8TDFGM',
#   'B01F67NVUW',
#   'B01CTIJEIY',
#   'B0175PT3KK',
#   'B00ZUE0LDM',
#   'B00G5L867C'],
#  'A19HVHRZDYFEOP': ['1620213982',
#   'B017VUV0VY',
#   'B01BL54RPQ',
#   'B01E1RQ27M',
#   'B001BROT1M',
#   'B00FE90M0K',
#   'B00SZPM4ZQ',
#   'B00G5L867C',
#   'B00IQCK42I',
#   'B00016WULK'],
#  'A19JM38B861BO4': ['B003TO06K8',
#   'B00BPEMPPS',
#   'B004R783GU',
#   'B001F0QXTQ',
#   'B00J2SMQLM',
#   'B00028ORTK',
#   'B00TUDND9I',
#   'B01A5TLI2O',
#   'B002K5SWA8',
#   'B01EQRTNHS'],
#  'A19KGY3W1P0MHT': ['B017CHORY8',
#   'B006IB5T4W',
#   'B01174YHM4',
#   'B00SIGOKEK',
#   'B000V2MBZ4',
#   '1620213982',
#   'B005VGT2NY',
#   'B01EL2BQ00',
#   'B00SV5RTAK',
#   'B007EITOSK'],
#  'A19KJPOF3QOJ24': ['B000FOI48G',
#   'B00540TG8S',
#   'B000FI4S1E',
#   'B0000530HU',
#   'B00120VWTK',
#   'B00B1IV2A2',
#   'B01G08QMAW',
#   'B00NH7UB48',
#   'B000FOI48G',
#   'B00PYFW05O'],
#  'A19U5RT4Q8Q1T6': ['B01FWZJIBY',
#   '1620213982',
#   'B01G7TWQH2',
#   'B00592MMPA',
#   'B01D7HTJ4K',
#   'B0013NB7DW',
#   'B000WYJTZG',
#   'B0010DMNFQ',
#   'B006WYJM8Y',
#   'B01CBB6WMA'],
#  'A1AQNQUNX8B6JT': ['1620213982',
#   'B007EITOSK',
#   'B000I6AZHE',
#   'B0152I7JX0',
#   'B0014BB6WA',
#   'B000FOI48G',
#   'B000PKKAFK',
#   'B00EP1N77I',
#   'B00ECMJT3G',
#   'B018SFIGXG'],
#  'A1ARU0IN6RUFFD': ['B010OT8OYA',
#   'B00W259T7G',
#   'B00014EO48',
#   'B001KYNZ5M',
#   'B01DDQXRWU',
#   'B01BRJ8TF0',
#   'B001LNODUS',
#   'B01AAVIO38',
#   'B000050B6H',
#   'B000FOI48G'],
#  'A1BB4635KSKDMV': ['B01E709KWW',
#   'B00UIVI8TQ',
#   'B01HFP5RAK',
#   'B000050FDY',
#   'B011I8D6L2',
#   'B016KWSIM8',
#   'B017RDO9TA',
#   'B00AFISVWQ',
#   'B000FOI48G',
#   'B000BJ1CGQ'],
#  'A1BCC7X6KRTBG0': ['B00JVU3K9I',
#   'B005EOOW74',
#   'B01E7UKR38',
#   'B01BMSGEQW',
#   'B01EJ03G16',
#   'B0189NOD4I',
#   'B00PMB54OE',
#   'B001MPXPQS',
#   'B01D0SJC7K',
#   'B00DPNJYJW'],
#  'A1BPJ56BXENC7': ['B01AX3AKQW',
#   'B00D3M0CRS',
#   'B0136MDZ9G',
#   'B013M4EHFY',
#   'B00TISI070',
#   'B0012C9UGK',
#   'B00GW58YC8',
#   'B01D5LPRC6',
#   'B01GCLNY6C',
#   'B01G9RPHZU'],
#  'A1C0RI6W65FC8B': ['B004JU08EA',
#   'B000SZVX3U',
#   'B00I6Q118K',
#   '1620213982',
#   'B01DBML2DC',
#   'B0002MQ9GK',
#   'B01E6NITSG',
#   'B00MGK9Z8U',
#   'B000FOI48G',
#   'B00A6YINXQ'],
#  'A1C60LJGZVEK27': ['B000FOI48G',
#   'B00JFSE75C',
#   'B019809F9Y',
#   'B006LTTBMW',
#   'B00OFMSBYG',
#   'B01E12HBZ4',
#   'B012GA0UTW',
#   'B00YYWCZLW',
#   'B002DHVAZW',
#   'B00PYFR9PK'],
#  'A1CB2SMS3TD44Z': ['B00PJD7KPG',
#   'B008U1Q4DI',
#   'B000VV1YOY',
#   'B000OV40LA',
#   'B014SAJCWE',
#   'B01D1MEBC6',
#   'B0191JMIO6',
#   'B00Q9MK5YO',
#   'B000142ZFS',
#   'B00EYZY6LQ'],
#  'A1CNSU8P68CPLT': ['B01E1SKHVI',
#   'B00D8FUHFC',
#   'B00CQ16CT4',
#   'B01ET9STT6',
#   'B002VPACWS',
#   'B00NT0AR7E',
#   'B000FOI48G',
#   'B00JVU3K9I',
#   'B01DOT2I5S',
#   'B0167JTCOM'],
#  'A1CSDWBYUJBCJZ': ['B00ESL6GT6',
#   'B01CD7JK9E',
#   'B0009R14YK',
#   'B00N57PFKK',
#   'B01EWU9DCE',
#   'B0012Y0ZG2',
#   'B00YO55LJC',
#   'B00BMW24TU',
#   'B000MT1GHA',
#   'B000WYJTZG'],
#  'A1CTNNVIYHO25P': ['B00JYGWWIO',
#   'B00G0U5RUW',
#   'B00FVVRKVA',
#   'B00HN9GCTE',
#   'B017CHORY8',
#   'B00N41CDXY',
#   'B000XQFBSM',
#   'B001QY8QXM',
#   'B006IB5T4W',
#   'B00PZW2R54'],
#  'A1CTQF97HFYOZB': ['B00D6H8AJM',
#   'B001AJ8YGC',
#   'B01G6XRGFQ',
#   'B000GLRREU',
#   'B00JVU3K9I',
#   'B00YMLWSDU',
#   'B0009W7MDM',
#   'B01GJ2ATGC',
#   'B009JP1T9S',
#   'B01H640HTG'],
#  'A1D5C2H9UFZHPU': ['B00U1VSN98',
#   'B001F51RBU',
#   'B00LYAZF64',
#   'B015NRYNPC',
#   'B006IB5T4W',
#   'B01DKQAXC0',
#   'B00Z2TP01S',
#   'B0188YXD5I',
#   'B00XC8OIDC',
#   'B000FOI48G'],
#  'A1D5UVH72Z6NJ1': ['B00JVU3K9I',
#   'B0001HYKBC',
#   'B00HFXW45E',
#   'B002O2JXWS',
#   'B00O86M4VA',
#   'B0007KXW1M',
#   'B01E4TVXGW',
#   'B00YNK9T3C',
#   'B0176NYLF8',
#   'B01DKQAXC0'],
#  'A1DAUVZRVSLLNW': ['B00G5L867C',
#   'B00VF344X0',
#   'B0013NB7DW',
#   'B00IA79SX0',
#   'B000FOI48G',
#   'B00JIESMR2',
#   'B000GLRREU',
#   'B01FHVAVFK',
#   'B00RN4XBNY',
#   'B00009RB0Y'],
#  'A1DCZ9882PXLVB': ['B01DKQAXC0',
#   'B005M2C6PS',
#   'B01DOJ0NWI',
#   'B00I2WUDK0',
#   'B01EL2BQ00',
#   'B004EBPD3K',
#   'B001E0C9LI',
#   'B014C2IGM0',
#   'B00AOBJCJK',
#   'B000WYJTZG'],
#  'A1DZ63D35BNT86': ['B00A8LH7AC',
#   'B01D9DA62Q',
#   'B00009RB1C',
#   'B00021KD2C',
#   'B010L2OYZI',
#   'B011WIYXI8',
#   'B00Q794RMA',
#   'B01E1DOTMG',
#   'B00N254KVU',
#   'B00NT0AR7E'],
#  'A1E0QCKB4R2X8X': ['B001QY8QXM',
#   'B000FED5DU',
#   'B019QAF22K',
#   'B01DBRRHX6',
#   'B00HWL3KRU',
#   'B00PEFFTT8',
#   'B00LXU3T1S',
#   'B000FED5DU',
#   'B003XS017S',
#   'B007SA3AUW'],
#  'A1E76OZZ5YUWVA': ['B00JVU3K9I',
#   'B000GLRREU',
#   'B0017LO24Q',
#   'B00CQ16CT4',
#   'B00120VWTK',
#   'B00D3M0CRS',
#   'B000FOI48G',
#   'B004EMKRE4',
#   'B00W259T7G',
#   'B000THHNIQ'],
#  'A1EBHZPAYMILW9': ['B00MLO4DWO',
#   'B000FEF1V4',
#   'B00KYEFE8A',
#   'B00WR5RNUQ',
#   'B00IZG78WY',
#   'B001QY8QXM',
#   'B0012Y0ZG2',
#   'B000FEF1V4',
#   'B015Q98HPO',
#   'B000KNELAW'],
#  'A1EJVNGBY5GM5I': ['B001P2NRPC',
#   'B00NV6LGDA',
#   'B00BMW24TU',
#   'B000FOI48G',
#   'B000BGQ98A',
#   'B00NOFU1IY',
#   'B01EADYY1I',
#   'B00VF344X0',
#   'B000FOI48G',
#   'B007K6LID0'],
#  'A1ER0356V2DSKW': ['B00A8ORITE',
#   'B00D3M0CRS',
#   'B001F51RBU',
#   'B004E3ION4',
#   'B00VF344X0',
#   'B005V3AUK6',
#   'B00DXMK1H4',
#   'B00LCO3EEW',
#   'B005VEYDJE',
#   'B001QY8QXM'],
#  'A1EY751AUVO5NZ': ['B01AHSUT8M',
#   'B00JFFSI8M',
#   'B01DKQAXC0',
#   'B000068PBL',
#   'B01DKQAXC0',
#   'B0172DMOL0',
#   'B00KU8NYZU',
#   'B005VIKDG2',
#   'B017BJ8KFE',
#   'B00H4C6L2I'],
#  'A1EZFX1TRHSAJX': ['B00MW3MV4G',
#   'B001J78QNG',
#   'B0085RZLVS',
#   'B0067F28ZW',
#   'B01ET9STT6',
#   'B00021VLXM',
#   'B01ENS6XDC',
#   'B00P0BODX4',
#   'B005IHT94S',
#   'B01CDEJ1H8'],
#  'A1F08GM4B97FV': ['B010KFK26Q',
#   'B00GW58YC8',
#   'B00W259T7G',
#   'B0049BAPBA',
#   'B00W259T7G',
#   'B011NWY734',
#   'B0091JMCPM',
#   'B01FTIQ18C',
#   'B00592MMPA',
#   'B00CBYCNNK'],
#  'A1F6EFMBK795DJ': ['B004BC62MI',
#   'B00009RB0Z',
#   'B002OITLG0',
#   'B01CTQC9J2',
#   'B01GQ12URM',
#   'B000NWMOBS',
#   'B0000530HU',
#   'B000MAV2XW',
#   'B008U1Q4DI',
#   'B01G203TN6'],
#  'A1FC8Y896NZP4T': ['B0067F28ZW',
#   'B000FOI48G',
#   'B00F029PWC',
#   'B000GLRREU',
#   'B002OITLG0',
#   'B000273BM0',
#   'B01G53GFKO',
#   'B000FEF1V4',
#   'B00HTMBJZ2',
#   'B00FIUEIY6'],
#  'A1FKIAKVOBNN7Y': ['B015ZOWER2',
#   'B00NNLURMY',
#   '1620213982',
#   'B01CT95TFK',
#   'B00L1I1VMG',
#   'B0001TMDF0',
#   'B004K4LFD8',
#   'B00L1I1VMG',
#   'B0190K7SQE',
#   'B002OITLG0'],
#  'A1FKUBRPLG6Y8I': ['B006WYJM8Y',
#   'B00CQ16CT4',
#   'B004MBJL58',
#   'B01F6K2IEE',
#   'B0190PBXQA',
#   'B00YNK9T3C',
#   'B00CW91G3M',
#   'B01GJI1N5C',
#   'B00RNKER4U',
#   'B000FED5DU'],
#  'A1G2HL4W8B3TA0': ['B01DYT2TIO',
#   'B0083UAUJ0',
#   'B01DKQAXC0',
#   'B000FED5DU',
#   'B00W259T7G',
#   'B01AUP9LMW',
#   'B00X8LM98Y',
#   'B00CSH32TY',
#   'B00AV2YL98',
#   'B00KH2DIAA'],
#  'A1G8Z9IKJ0BD1M': ['B011A7BW2Q',
#   'B01ENS6XDC',
#   'B01D25U784',
#   'B004BRN154',
#   'B0010ZBORW',
#   'B00TKJET7W',
#   'B00MXQ7E94',
#   'B0013NB7DW',
#   'B00X8LM98Y',
#   'B01CTWGBD6'],
#  'A1GEJ55RJGD7JW': ['B008E0DBYA',
#   'B005VEDOD0',
#   'B00RMNFHVK',
#   'B018FHNNH6',
#   'B0043RL0SC',
#   'B01CD7JK9E',
#   'B001QY8QXM',
#   'B00IPVCCVQ',
#   'B00RW5XH10',
#   'B01DKQAXC0'],
#  'A1GIYGD23YIDTN': ['B017X3BSP2',
#   '1620213982',
#   'B0168SXRR0',
#   'B004BC62MI',
#   'B00QHZFSE0',
#   'B017M402PO',
#   'B006IB5T4W',
#   'B017UF16TQ',
#   'B004R783GU',
#   'B01FUK8RMM'],
#  'A1GLG2IZBZHRAJ': ['B00005JS5C',
#   'B0054EU4Z8',
#   'B01CTQC9J2',
#   'B00J9MJDFS',
#   'B01BO724A6',
#   'B002BX3PPG',
#   'B013PVOGVY',
#   'B005YH8LLO',
#   'B00I2W34HY',
#   'B0199MCGTW'],
#  'A1H1T82FPO20DN': ['B00GW51XFS',
#   'B00NFV7IPG',
#   'B00D3M0CRS',
#   'B016V8YWBC',
#   'B019809F9Y',
#   'B00HSBLQ2U',
#   'B00BMVV3MK',
#   'B00V79P04E',
#   'B005JK5T20',
#   'B00CFDBOKA'],
#  'A1H7JDZ9BKTKGC': ['B010B5ZE4U',
#   'B001CS2JEO',
#   'B000WZHGVY',
#   'B00ZNJMK9C',
#   'B0051MQ3LW',
#   'B017CHORY8',
#   'B004MBJL58',
#   'B00NB96EI4',
#   'B000VUXCGI',
#   'B00NK3E30C'],
#  'A1HBROZPSV5KT6': ['B008U1Q4DI',
#   'B00DV76LU2',
#   'B017HAMEZE',
#   'B000YB70PS',
#   'B019BCAMT6',
#   'B00YDABOXK',
#   'B00NV6DMG4',
#   'B000NQ6PJ6',
#   'B01CDEJ1H8',
#   'B00RFE2W5A'],
#  'A1HBXMUIHTAIU2': ['B00JVU3K9I',
#   'B00QJ9YPZM',
#   'B000FOI48G',
#   'B000EG8HLE',
#   'B017CHORY8',
#   'B017JSZKGY',
#   'B019Z9KL00',
#   'B01B9RU75K',
#   'B000URXP6E',
#   'B009SAVQ7E'],
#  'A1I32A4SA9W2L2': ['B001OHV1H4',
#   'B0012Y0ZG2',
#   'B00OHGNAD2',
#   'B00FKX918O',
#   'B000YB70PS',
#   'B01EWYV6VQ',
#   'B00517W5LY',
#   'B01ENS6XDC',
#   'B01H5X3A5G',
#   'B004LXKY4E'],
#  'A1IDJ6KR8CQV9I': ['B000HGJLL6',
#   'B0175PT3KK',
#   'B00B6YWV74',
#   'B001AJ6YS2',
#   'B001OHV1H4',
#   'B0112K2KP4',
#   'B0012Y0ZG2',
#   'B00LMCQPRC',
#   'B01CV597NM',
#   'B00HLXYMI0'],
#  'A1II0TTUUE2C7Y': ['1620213982',
#   'B00E4WVU3Q',
#   'B00JCZTDFC',
#   'B00157OBRU',
#   'B00FPGH0V6',
#   'B000BJ1CGQ',
#   'B006MRPMMG',
#   'B00L1I1VMG',
#   'B0183FI492',
#   'B000GLRREU'],
#  'A1ILEZFIVOU0EP': ['B000209JS2',
#   'B0025PW1DW',
#   'B00CQ16CT4',
#   'B00VJ4H6Y4',
#   'B01GO2E4EA',
#   'B00PYFR9PK',
#   'B00XGVV2MA',
#   'B006IB5T4W',
#   'B01EIP4LMU',
#   'B00RQWAWBC'],
#  'A1ITJ5M7I9G7FR': ['B00B7K0Z8E',
#   'B000EE9XYG',
#   'B004LQNVPA',
#   'B005GMY86O',
#   'B00L3LUQ9A',
#   'B00BMVV3MK',
#   'B000GLRREU',
#   'B000BJ1CGQ',
#   'B00LZB9A7C',
#   'B00EC21OIE'],
#  'A1IWTXM1SJWHDN': ['B018TZTS96',
#   'B006U7NSO2',
#   'B000FOI48G',
#   'B01DKI7B46',
#   'B000EPUQKK',
#   'B011JG1K3E',
#   'B0053OTNOW',
#   'B01CNLMWE0',
#   'B000FOI48G',
#   'B000MRK5EW'],
#  'A1J2NTTE63GNG2': ['B00U70ONTW',
#   'B00079FOIW',
#   'B00DR68TOI',
#   'B00D5UUYFS',
#   'B000GCLR40',
#   'B00UIEUYHW',
#   'B000WYJTZG',
#   'B01CTQC9J2',
#   'B00P85Q3JY',
#   'B0168SXRR0'],
#  'A1JRREJ5D62LFF': ['B00PYFR9PK',
#   'B017NA063A',
#   'B01CTQC9J2',
#   'B005ROU5U4',
#   'B0017DQ0U8',
#   'B0014AX89K',
#   'B00LYUQPQ8',
#   'B01DSDPEZ6',
#   'B00B4OTTKS',
#   'B000FTYALG'],
#  'A1KGMTEXL70WF6': ['B000FEF1V4',
#   'B0026TMWK4',
#   'B00I8S1UCI',
#   'B014LHAEW6',
#   'B0012615W8',
#   'B00W259T7G',
#   'B000FOI48G',
#   'B00GXD27OK',
#   'B00FB2WUWI',
#   'B00009RB1C'],
#  'A1KWUQZJ1Z6MN2': ['B00QFHQUCO',
#   'B005IHT94S',
#   'B00016WULK',
#   'B01EGH00J8',
#   'B002DHVAZW',
#   'B01D5JBIL2',
#   'B01DQ6IRT0',
#   'B009WNYL8I',
#   'B001F51R9M',
#   'B00DV76LU2'],
#  'A1LXJ8XCGNBXOF': ['B0189CM3U0',
#   'B0070D9R8G',
#   'B01DKQAXC0',
#   'B006U7NSO2',
#   'B01BYP4TM4',
#   'B01AUOTSVW',
#   'B01CTIJEIY',
#   'B018E71TKU',
#   'B001LE2Q0G',
#   'B00U52GXX6'],
#  'A1M8YMS915ZK0B': ['B001ET77OI',
#   'B003I5VN7I',
#   'B000BJ1CGQ',
#   'B00I86O3WE',
#   'B0189NOD4I',
#   'B00009RB0Z',
#   'B002EF0FAE',
#   'B001AJ6YS2',
#   'B00ZYYYLNY',
#   'B016QQJFRK'],
#  'A1NDRR3G9SJF18': ['B000H29ZOI',
#   'B00B7K0Z8E',
#   'B00BWIT33Y',
#   'B00CD6X9G6',
#   'B00112DRHY',
#   'B001QY8QXM',
#   'B00LM8WVQA',
#   'B01GQUYS6O',
#   'B00KBQFY22',
#   'B00IXHBQ5U'],
#  'A1NE6K8PXW780O': ['B000FOI48G',
#   'B0153R4C44',
#   'B00H1M8R3C',
#   'B000FOI48G',
#   'B00YFQ3Q9W',
#   'B00O5YNZFY',
#   'B0114CGE8E',
#   'B000FI4S1E',
#   'B0180VBNWO',
#   'B000WYJTZG'],
#  'A1NEG0FRW5FDBL': ['B01BZV6VVY',
#   'B0017I8Z6K',
#   'B00ANQ8DOQ',
#   'B011JG1K3E',
#   'B019809F9Y',
#   'B01CDEJ1H8',
#   'B00FIUEIY6',
#   'B00HNK96UK',
#   'B008YQM44C',
#   'B011773GBE'],
#  'A1NN82RWB6PXJW': ['B00G03YKGG',
#   'B00KEYUI7C',
#   'B006MRPMMG',
#   'B004JCBJBO',
#   'B000146LKS',
#   'B00GM30OEG',
#   'B00EBZD0PW',
#   'B01AAVIO38',
#   'B00009RB1C',
#   'B00185SPJO'],
#  'A1NY67EVWD6CD6': ['B014GJUGTA',
#   'B018WCT01C',
#   'B0171BTD8U',
#   'B00MJYKHQC',
#   'B0018OVL4G',
#   'B01B6YTFRC',
#   'B00ROPHPAC',
#   'B00C6NZH3E',
#   '1620213982',
#   'B00GAFKXAQ'],
#  'A1OB41VQHXZ0R8': ['B0017DQ0U8',
#   'B001F51QXO',
#   'B00LP9UFYG',
#   'B00021DJ32',
#   'B001AJD0UM',
#   'B01G37STL0',
#   'B00D3M0CRS',
#   'B00GW58YC8',
#   '3772440908',
#   'B00005JS5C'],
#  'A1OJ2IXX8F7Q7X': ['B017DXCGY4',
#   'B00005JS5C',
#   'B00LWVNVXO',
#   'B00W259T7G',
#   'B00PGQALL6',
#   'B01E6NITSG',
#   'B001AJ8YGC',
#   'B011FIJLMI',
#   'B00IZG78WY',
#   'B001AJ6YS2'],
#  'A1OTIUDE7LWAGT': ['B00NLNO554',
#   'B0012Y0ZG2',
#   'B000146LKS',
#   'B000YB70PS',
#   'B000TVPOGK',
#   'B001K80AYM',
#   'B001QY8QXM',
#   'B00EQ4WVR6',
#   '1620213982',
#   'B01D54YO3G'],
#  'A1P1OHYJOOZX5P': ['B0054EU4Z8',
#   'B01BZQSZPO',
#   'B000GLRREU',
#   'B007SA3AUW',
#   'B01BPEUXUG',
#   'B006E5TV0K',
#   'B01B9RU75K',
#   'B00159JOIO',
#   'B013WR0B6U',
#   'B000BJ1CGQ'],
#  'A1PFDA9SL15S4O': ['B01DTEPAHG',
#   'B00S9A7IN0',
#   'B0017WIL0Q',
#   'B00C6CCD8C',
#   'B000FOI48G',
#   'B000YB70PS',
#   'B00JE3PWPW',
#   'B002N5MI3W',
#   'B01ENL20AE',
#   'B00Q9N2IYI'],
#  'A1PKBKALGLSX0Z': ['B00BMW24TU',
#   'B00BMVV3MK',
#   'B004EFECYC',
#   'B00NFU74GU',
#   'B01CM6T2W6',
#   'B00Q794RMA',
#   'B015DBHF8K',
#   'B00G9IRRCG',
#   'B00NR90T0W',
#   'B00GSKNWFG'],
#  'A1PMLXHE863GR6': ['B0067F28ZW',
#   'B01BQR7TK4',
#   'B01B18T01Y',
#   'B00T6PYPII',
#   'B00V7W2BNY',
#   'B004CG4ZGS',
#   'B004BRN154',
#   'B00NNLKABW',
#   'B00QSLD10Q',
#   'B006MRPMMG'],
#  'A1PR178735XC70': ['1620213982',
#   'B017VKN7RO',
#   'B005EDVGDI',
#   'B00EC21OIE',
#   'B018LPJR5O',
#   'B0013YXQ58',
#   'B001QY8QXM',
#   'B011I721OG',
#   'B005T7VA4Y',
#   'B019NNXYJS'],
#  'A1PXO67EUM5HJQ': ['B00I9JIAFG',
#   'B00PX1R0OU',
#   '1620213982',
#   'B001RK0S7C',
#   'B000X2FPXC',
#   'B0054EU4Z8',
#   'B007QG7G3U',
#   'B01EJTVZY2',
#   'B00N1OBQ2S',
#   'B00ATV35SY'],
#  'A1QHS58JVFLF3I': ['B00TA1Y79U',
#   'B00B35ICCO',
#   'B00RYMOI0U',
#   'B01DUWXTS4',
#   'B00UW6XGRQ',
#   'B01G3U70A8',
#   'B01GR1XP34',
#   'B001CUU9KI',
#   'B01EGAJMBC',
#   'B001AJ6YS2'],
#  'A1QPKRHCAOQVZ5': ['B0054PCP0O',
#   'B00ROPI98E',
#   'B001DYFIPY',
#   'B001F51RAG',
#   'B000GLRREU',
#   'B01D5JBH7M',
#   'B005XHEEZM',
#   'B01FNJ9MOW',
#   'B015NMJGSG',
#   'B01ENNJEPQ'],
#  'A1R2TTULP0Z2BM': ['B00S8JQKEA',
#   'B0002W09UC',
#   'B00F550JWE',
#   'B000MOH552',
#   'B00KU16IEG',
#   'B004D3WVWU',
#   'B017J1C0HI',
#   'B0010ZBORW',
#   'B000GCOIMI',
#   'B00B46UFD6'],
#  'A1R8GBYBJWWWU0': ['B00ZPVJ8MK',
#   'B00UW60M3C',
#   'B00SS2QOOI',
#   'B00120VWTK',
#   'B01FKYDORQ',
#   'B00005JS5C',
#   'B00YFP8R1K',
#   'B000GLRREU',
#   'B000EG8HLE',
#   'B00GW557GE'],
#  'A1RAXJN2Q4V20X': ['B00YBWDW6C',
#   'B00M7BX6Y2',
#   'B01GKZ14SU',
#   'B005M2C6PS',
#   'B00NV6LT5A',
#   'B00028Q7IO',
#   'B0000530HU',
#   'B000PA3B6A',
#   'B000WYJTZG',
#   'B001MW1MK2'],
#  'A1RCMCAJR2LJA4': ['B0010DMNFQ',
#   'B00KW7OMQY',
#   'B00T175AP8',
#   'B00YQBYO1K',
#   'B00JUMQINW',
#   'B00020UR4C',
#   'B000J1HR6U',
#   'B00W259T7G',
#   'B014012MBE',
#   'B001E5PLCM'],
#  'A1RE2XA5HQD1D3': ['B011C0F1WI',
#   'B019ZQTXSO',
#   'B01C4ZAPGM',
#   'B006IB5T4W',
#   'B00Y11Q7CY',
#   'B011AKOVGW',
#   'B000P4CAEK',
#   'B00028Q7IO',
#   'B00011QUDE',
#   'B008YGE0T4'],
#  'A1RMLPJ1PF8LGV': ['B00NV6MCWY',
#   'B015PO17CK',
#   'B0117ZM9W8',
#   'B00LLLXEUA',
#   'B000PKNPES',
#   'B00ARM4Q7O',
#   'B00WWP5FHO',
#   'B01DKQAXC0',
#   'B00BHLQGMC',
#   '1620213982'],
#  'A1RX2ODQRQZVSI': ['B0012Y0ZG2',
#   'B007SPA4NS',
#   'B00NE5Q9JO',
#   'B00LP9UFYG',
#   'B000GLRREU',
#   'B001CUU9KI',
#   'B000050FDY',
#   'B00592MMPA',
#   'B000WZHGVY',
#   'B01CQSJF9U'],
#  'A1S3NMNTSO6GW': ['B00RYGTT2S',
#   'B00CQ7ZMXK',
#   'B00IWXYB0W',
#   'B01BXFIBY2',
#   'B00GQOTDZC',
#   'B000FOI48G',
#   'B00005JS5C',
#   'B000FOI48G',
#   'B01CI90F2I',
#   'B01G50P4KO'],
#  'A1S6OQV823B53J': ['B00021DJ32',
#   'B00PSYOU90',
#   'B000WYJTZG',
#   'B016QSRYR6',
#   'B0054H0NZ6',
#   'B00DT4757A',
#   'B0016JDQP0',
#   'B00Y37SAG2',
#   'B017JFEU0O',
#   'B013XKHA4M'],
#  'A1SA3N793WT2LM': ['B004A7NXG2',
#   'B003983HRI',
#   'B0009WY5AA',
#   'B00IU0TWHO',
#   'B00PJD7KPG',
#   'B002CMUHDY',
#   'B00B9M5S3C',
#   'B0013NB7DW',
#   'B00MJYKHQC',
#   'B0054H0NZ6'],
#  'A1SA932MLERVQY': ['B00J6QBG3O',
#   'B00YWFTNNE',
#   'B011KSK8P2',
#   'B00020UR4C',
#   'B019FOXB70',
#   'B00BMW24TU',
#   'B000WYJTZG',
#   'B00R8J13W0',
#   'B00021DJ32',
#   'B00SQ3S6TA'],
#  'A1SCZBXGPJ2615': ['B008U1Q4DI',
#   'B00Q9FFZHS',
#   '1620213982',
#   'B011JG1K3E',
#   'B00VTR692G',
#   'B00W259T7G',
#   'B01DDQXRWU',
#   'B00LSA27AM',
#   'B000PARERW',
#   'B01CZW1FTU'],
#  'A1SMXRCNRO4ZQM': ['B00C93ADUI',
#   'B01FQR3ZRG',
#   'B00EZFUZA6',
#   'B01DKQAXC0',
#   'B00BDB2RLA',
#   'B00QTQ66IY',
#   'B001FYUZAU',
#   'B01GR53BUC',
#   'B00H78Q0XE',
#   'B0013NB7DW'],
#  'A1T1N2585E1T0D': ['B00IIZG80U',
#   'B018AVVYAK',
#   '1620213982',
#   'B00M4JTQBO',
#   'B000EG8HLE',
#   'B002OXSKF8',
#   'B0013ANMBU',
#   'B00BMVV3MK',
#   'B000GLRREU',
#   'B005VGT2NY'],
#  'A1TEKLMF4V1X2C': ['B016E8RZQS',
#   'B00PHMM3LK',
#   'B00BEGEQNQ',
#   'B002AL0MZ0',
#   'B01DMTSLO2',
#   'B00BMVV3MK',
#   'B002RZZXYE',
#   'B00QUUHILS',
#   'B0012E60C0',
#   'B008O0ZTPO'],
#  'A1TF44D9KYAD60': ['B00MGLBA3W',
#   'B01CDEJ1H8',
#   'B019D1XQ4S',
#   'B01AWA2WIU',
#   'B00ZUR15F2',
#   'B002CMLRX8',
#   'B008E0DBYA',
#   'B000VPWGNS',
#   'B00015XAQA',
#   'B006MRPMMG'],
#  'A1TGP1VTM3KCTI': ['B000FI4S1E',
#   'B00Q794RMA',
#   'B00F2RADYY',
#   'B018WCT01C',
#   'B000FEF1V4',
#   '1620213982',
#   'B00KX6IPXK',
#   'B006530MW2',
#   'B00LTK54LK',
#   'B00SHV7ABQ'],
#  'A1TK5M6EM3GS3C': ['B00G5L867C',
#   'B00120VWTK',
#   'B002CVTVV4',
#   'B0043RL0SC',
#   'B000EG8HLE',
#   'B000XV745A',
#   'B0111R6248',
#   '1620213982',
#   'B000GLRREU',
#   'B001UQ70O2'],
#  'A1TO3GV14TGF2R': ['B0010H91ZM',
#   'B01BKIBT5K',
#   'B00OXDWFG2',
#   'B015SG1BSU',
#   'B013NEZMZC',
#   'B00BMVV3MK',
#   'B01AQ2E9IK',
#   'B017XHB2A4',
#   'B01FIQV4ZU',
#   'B00DT4757A'],
#  'A1TP9JHTIY468V': ['B00PVZUSZ6',
#   'B01E0TOXC2',
#   'B00JDZ3O2O',
#   'B01DKQAXC0',
#   'B0017TZD7S',
#   'B00OFQ9UDI',
#   'B000XVXK12',
#   'B00OINB5CC',
#   'B0194D91RG',
#   'B0049UKUYS'],
#  'A1UAOE8KO7Q1DZ': ['B00016WU6A',
#   'B000FOI48G',
#   'B006U7NSO2',
#   'B007V6JNE0',
#   'B004BC62MI',
#   'B00005JS5C',
#   'B01D2Y6LDK',
#   'B001QY8QXM',
#   'B00CKECOJE',
#   'B001QY8QXM'],
#  'A1UDCDY6ZNE83T': ['B000FEF1V4',
#   'B000EE9XYG',
#   'B000FP35E8',
#   'B00X4DKZKU',
#   'B00RG8EEAG',
#   'B000H6A02A',
#   'B01E8J1IHM',
#   'B00O83QGWQ',
#   'B008U1Q4DI',
#   'B005VGT2NY'],
#  'A1UUNKRU1DTZTL': ['B003QYSO46',
#   'B01DKQAXC0',
#   'B000WYJTZG',
#   'B000GLRREU',
#   'B0175PT3KK',
#   'B00GP4JCOA',
#   'B01BZV6VVY',
#   'B000UK2VRK',
#   'B00GMPUFPW',
#   'B01C4IL2TS'],
#  'A1V0UJQ4XGAJ3H': ['B0001D35FI',
#   'B01DKI7B46',
#   'B000PA3B6A',
#   'B00OOEAC1K',
#   'B0026DE7NK',
#   'B000YB70PS',
#   'B017JR0P3S',
#   'B01ATY94XK',
#   'B00CQ16CT4',
#   'B005LN5I3A'],
#  'A1VBZLO2JGYU1B': ['B01CGU3DXC',
#   'B01GAFCQOQ',
#   'B000GLRREU',
#   'B00WDPM2M4',
#   'B01AVJCDYA',
#   'B0175PT3KK',
#   'B000FVHRXC',
#   'B00K8FN0FY',
#   'B00D3M0CRS',
#   'B017XDBUSW'],
#  'A1VC6YCAFKV6Q': ['B0018BYKW4',
#   'B000FOI48G',
#   'B01CTQC9J2',
#   'B01G29C9VA',
#   'B01A4NGQNW',
#   'B01EGH00J8',
#   'B0169KFICY',
#   'B000FOI48G',
#   'B01G7MXSXK',
#   'B01DYTTNTW'],
#  'A1VVEX78B2TYBX': ['B005I8RH78',
#   'B00MJ9PUWS',
#   'B00005JS5C',
#   'B000FOI48G',
#   'B0017I8Z6K',
#   'B00W259T7G',
#   'B000NY66DS',
#   'B002RTUK70',
#   'B00LGLLY7K',
#   'B001OD1CAY'],
#  'A1VVQ2DFL0QLXF': ['B00B7G9I5O',
#   'B001Q2FMA4',
#   'B0012E60C0',
#   'B0010ZBORW',
#   'B00VF344X0',
#   'B01B6YTFRC',
#   'B00BMVV3MK',
#   'B004Z5H0XG',
#   'B000IQSU0I',
#   'B017HJEZCK'],
#  'A1VYWSQ2OXLH98': ['B014EJI11W',
#   'B01DKI7B46',
#   'B00LHI1U7Q',
#   'B01F12XRL0',
#   'B00005JS5C',
#   'B00005JS5C',
#   'B00M5IBAZY',
#   'B000050B6B',
#   'B006VS7VJ8',
#   'B000PARERW'],
#  'A1WEFBEJ7OHSVZ': ['B00MY6FBJS',
#   'B005PWE9PA',
#   'B00005JS5C',
#   'B00I82CBUO',
#   'B00VGQ8VTY',
#   'B00X38I8CS',
#   'B00RVWYSI0',
#   'B00C2S9LQ2',
#   'B001E5PLCM',
#   'B00YE5TQ9I'],
#  'A1WOX40GUAFDKW': ['B003PP0CPU',
#   'B000BJ1CGQ',
#   'B009K158UW',
#   'B010EWMLKK',
#   'B004LUQRJI',
#   'B000UK163K',
#   'B000SBL2EE',
#   'B005V3AV5U',
#   'B013VZRLB6',
#   'B000FOI48G'],
#  'A1WSZED2O5MA5T': ['B00VF344X0',
#   'B00TYBQTF6',
#   'B00D3M0CRS',
#   'B00FCGXHEI',
#   'B014N7WP5S',
#   'B00IU5EDKK',
#   'B00PAYDPT4',
#   'B00ARNTNL2',
#   'B000FED5DU',
#   'B013XKHA4M'],
#  'A1XBJBT6HORBLA': ['B010TQC4R6',
#   'B01H4EB5EE',
#   'B000EG8HLE',
#   'B00SBFJU02',
#   'B01CU328TK',
#   'B01GCLNY6C',
#   'B0090F0RX6',
#   'B00BMVV3MK',
#   'B00JF2QNEG',
#   'B0012Y0ZG2'],
#  'A1XHN6JF8A8W69': ['B000FOI48G',
#   'B0110H5Z8S',
#   'B001H0YT5Y',
#   'B002YMTLPM',
#   'B019E73XNK',
#   'B00JH3HH9S',
#   'B00SQ3S6TA',
#   'B00BQ1CDVQ',
#   'B00GC4HCSG',
#   'B00FGSV6QS'],
#  'A1XWCTARAQ0679': ['B014X59EEK',
#   'B00LP9UFYG',
#   'B01DQ9T05W',
#   'B012AZRFXM',
#   'B01AAVIO38',
#   'B018JIRGSI',
#   'B018QQU0YK',
#   'B0151MF970',
#   'B0016OYR12',
#   'B01GKK7HF4'],
#  'A1XZJ85PKMAZP0': ['B00LKQ2V5U',
#   'B0067F28ZW',
#   'B0002JHI1I',
#   'B0027BG0YK',
#   'B001PNCRNO',
#   'B013XKHA4M',
#   'B000WYJTZG',
#   'B01AQH55DS',
#   'B0070D9R8G',
#   'B005IHT94S'],
#  'A1YALF6PWOMS6S': ['B00FCGXHEI',
#   'B00D3M0CRS',
#   'B00LEWOG3U',
#   'B00W7U1208',
#   'B00I6Q1072',
#   'B000WZNZAA',
#   'B008RC03BY',
#   'B00PNBZGNW',
#   'B005V3AV5U',
#   'B007LQURMW'],
#  'A1YEO5KEW7M2GF': ['B00XD6UC7Y',
#   'B000050FDY',
#   'B0015TIGOC',
#   'B01DKQAXC0',
#   'B00MJYKHQC',
#   'B000URXP6E',
#   'B01FGA2X30',
#   'B01ACQ5PEC',
#   'B01CJLANUY',
#   'B01EQWGD4Y'],
#  'A1YQ33635DJEG5': ['B00BWIT33Y',
#   'B00DT4757A',
#   'B004I788UK',
#   'B00S4A9PD6',
#   'B00MGK9Z8U',
#   'B000FOI48G',
#   'B01B3R5EFO',
#   'B01DKQAXC0',
#   'B00BMVV3MK',
#   'B0016HOVZG'],
#  'A1YSAFP6T3JZ1C': ['B000GLRREU',
#   'B0010DMNFQ',
#   'B00HU9MH64',
#   'B000V86CUS',
#   'B00CCG7UZS',
#   'B00LBPDINO',
#   'B00GW58YC8',
#   'B01GAXQTEG',
#   'B018QQU0YK',
#   'B007H8X9ZG'],
#  'A1YTPCNXQ2LJ5Z': ['B0012Y0ZG2',
#   'B001QY8QXM',
#   'B001AMRQ2W',
#   'B0012Y0ZG2',
#   'B00Y40YTPY',
#   'B0058H0GA4',
#   'B01B54XW54',
#   'B00VB5N3X4',
#   'B01BLQ5D1C',
#   'B00P0BLZFI'],
#  'A1YVXZK51DEDPC': ['B00BMW24TU',
#   'B000GLB37M',
#   'B00ILXRPQ0',
#   'B00RJ638FM',
#   'B000GLRREU',
#   'B009PIJV1W',
#   'B00U9UQ8W0',
#   'B00MP12J4W',
#   'B000NN5HFW',
#   'B009XXQJ9G'],
#  'A1Z3GE09RDY6O7': ['B00OK03PJE',
#   'B00JOYE20C',
#   '1620213982',
#   'B0006O10P4',
#   'B00KGKQR2Y',
#   'B019IMB8TM',
#   'B01DKQAXC0',
#   'B008U1Q4DI',
#   'B00JFRPRYI',
#   'B010OT8OYA'],
#  'A1Z6IPI0G3QIUR': ['B000050FDY',
#   'B00EXJ0982',
#   'B009J62UJU',
#   'B000WYJTZG',
#   'B00P017Y1M',
#   '1620213982',
#   'B0179GD5CC',
#   'B007HNIE2E',
#   'B0002JGIZA',
#   'B0012Y0ZG2'],
#  'A1ZVXL7K0XY3S6': ['B01GWTZ05C',
#   'B00011QUDE',
#   'B01AVJCDYA',
#   'B000XZK7DC',
#   'B0012Y0ZG2',
#   'B00D2ZTMQI',
#   'B010DP5VQ4',
#   'B005NCIJV2',
#   'B000GLRREU',
#   'B001QY8QXM'],
#  'A1ZXYITUZM3Q6A': ['B000FOI48G',
#   'B003H3SD3I',
#   'B01H61A1MW',
#   'B010EWMLKK',
#   'B0048IH1SE',
#   'B00LH4DV1I',
#   'B00WQAM3M0',
#   'B00LPP3G2I',
#   'B018E71TKU',
#   'B00MQLH73Y'],
#  'A202BVEB76NTMK': ['B01HC9ONI6',
#   'B018E71TKU',
#   'B001V6WWIU',
#   'B00IAA21WW',
#   'B00JVU3K9I',
#   'B0067F28ZW',
#   'B01CV597NM',
#   '1620213982',
#   'B000B8WZUY',
#   'B019ZG9RZI'],
#  'A205S0BTPEFI0I': ['B0009MFUPY',
#   'B01G286XBS',
#   'B001A1NJOM',
#   'B013GTLEKQ',
#   'B000JUT8KY',
#   'B01GNYTNPO',
#   'B00R8R18FO',
#   'B006IB5T4W',
#   'B0026TMWK4',
#   'B000050FDY'],
#  'A20MSUD02BETH2': ['B00NT0AR7E',
#   'B01DLR9IDI',
#   'B00517W5LY',
#   'B000FOI48G',
#   'B00BMVV3MK',
#   'B0002MQ9GK',
#   'B01DFHDMS6',
#   'B01C2B3CFO',
#   'B01636G5SK',
#   'B000FI4S1E'],
#  'A20P2XESU3G3EC': ['B000WYJTZG',
#   'B000AADG60',
#   'B002BTFQAW',
#   'B00BPPK0SG',
#   'B0006M56BK',
#   'B00W259T7G',
#   'B001O4LYM4',
#   'B000FOI48G',
#   'B01EYVI6YC',
#   'B00CHO8VTE'],
#  'A20QY357E6SAF': ['B0017TZD7S',
#   'B000GLRREU',
#   'B001C7E9C0',
#   'B00R24JMBU',
#   'B000Q40BT0',
#   'B016V9YH4S',
#   'B000BKNAXS',
#   'B00REOJ1PA',
#   'B0013NB7DW',
#   'B00H3VQT40'],
#  'A20SJ2793OUCPW': ['B00LEWOG3U',
#   'B01DKQAXC0',
#   'B00YMM26VS',
#   'B01DLR9IDI',
#   'B01614ADHI',
#   'B01BEWYRJ2',
#   'B00009RB1C',
#   'B000FEF1V4',
#   'B000FOI48G',
#   'B00HWI6JA8'],
#  'A20T7NNNUHH60H': ['B00WQAMF9G',
#   'B01F49PRIQ',
#   'B00DT4757A',
#   'B00190PJBK',
#   'B00YO55LJC',
#   'B000EE9XYG',
#   'B00VB5N3X4',
#   '1620213982',
#   'B000X2FPXC',
#   'B018QQU0YK'],
#  'A21JL9NVA7KEMC': ['B001CUU9KI',
#   'B019LBMXBM',
#   'B01B5JW9NU',
#   'B000H6A02A',
#   'B000LIBUBY',
#   'B01HC6G4D6',
#   'B00B7K0Z8E',
#   'B0070IAT38',
#   'B01F1Y2YSK',
#   'B00BSE2OEC'],
#  'A21M4N08F3EU5J': ['B00GJ4G686',
#   'B00NB0PHRC',
#   'B001AJ6YS2',
#   'B00N92XB2U',
#   'B000FED5DU',
#   'B00MYM816W',
#   'B00G14QJA4',
#   'B000A2LRBY',
#   'B01DDQXRWU',
#   'B00LCA2PTQ'],
#  'A21NUBJVBS230S': ['B00070D21W',
#   'B00EP1N77I',
#   '1620213982',
#   'B017BJ8KFE',
#   'B014Q32GPS',
#   'B00W259T7G',
#   'B0086XP1O8',
#   'B002Q5T1S4',
#   'B008U1Q4DI',
#   'B00QBZ7D9E'],
#  'A21OELUKDF2E57': ['B01CTVK9B2',
#   'B01BZV6VVY',
#   'B005IC4V8C',
#   'B000H6A02A',
#   'B00JW2722Q',
#   'B0006M56BK',
#   'B000URXP6E',
#   'B0001XQNPW',
#   'B00C6CCD8C',
#   'B000A23CQM'],
#  'A21XQP90LEND9R': ['B0002PU864',
#   'B008VHPM6Q',
#   'B01D0I2TSY',
#   'B00PJ5CSWY',
#   'B000GLRREU',
#   'B013XKHA4M',
#   'B00C6N8A4C',
#   'B000EE9XYG',
#   'B01BZV6VVY',
#   'B0058A4ZOE'],
#  'A21YO11OY4KATO': ['B001F51RBU',
#   'B01BSL9DL6',
#   'B00HSSFEA8',
#   'B01BL1RAWW',
#   'B00AJECD2A',
#   'B000PKNPES',
#   'B0153R4C44',
#   'B002CT7RLW',
#   'B00NT0AR7E',
#   'B00U1VSN98'],
#  'A220EHDBIGBL30': ['B00573ODY4',
#   'B000FOI48G',
#   'B000S17FUO',
#   'B00NNLKABW',
#   'B00AFCP62K',
#   'B00T175AP8',
#   'B00005JS5C',
#   'B00EJDK82O',
#   'B008E0DBYA',
#   'B00X9U7ZP6'],
#  'A224YJVNU30DVM': ['B00G7XOZEG',
#   'B00GYKPNF2',
#   'B001QY8QXM',
#   'B00KM52L32',
#   'B001DYFIPY',
#   'B004IQA3TU',
#   'B00ATV35SY',
#   'B00VF344X0',
#   'B000RC2V4Y',
#   '1620213982'],
#  'A22A1B25VBD0YO': ['B00GYSOX78',
#   'B01A17YJC6',
#   'B006IB5T4W',
#   'B001QY8QXM',
#   'B000FOI48G',
#   'B000GLRREU',
#   'B00I2WUDK0',
#   'B003983HRI',
#   'B000FI4S1E',
#   'B0009RF9DW'],
#  'A22EWIMT2GUTTL': ['B00HX7AQ98',
#   'B000GLRREU',
#   'B00WIKHV1Q',
#   'B00LNRPFCC',
#   'B00W259T7G',
#   'B00FW6JXNM',
#   'B000NVIFGW',
#   'B007EITOSK',
#   'B00GWJW5MO',
#   'B016E8RZQS'],
#  'A22EZJLTPINCFS': ['B0096PCASU',
#   'B00MLO4DWO',
#   'B00W259T7G',
#   'B000WYJTZG',
#   'B00VF344X0',
#   'B01AUP9LMW',
#   'B00D3OX3EU',
#   'B000FEF1V4',
#   'B01C39X6TW',
#   'B00YQE6I8Y'],
#  'A22QJRB86RF6O1': ['B0013NB7DW',
#   'B00U29A4IC',
#   'B000V2MBZ4',
#   'B00YQBYO1K',
#   'B00OI60OEO',
#   'B01EIIVGXE',
#   'B01BZV6VVY',
#   'B013XKHA4M',
#   'B000JL7SGE',
#   'B00T175AP8'],
#  'A2320AUCHA95U2': ['B00KSG4DOU',
#   'B00P1RQBZ0',
#   'B01DKQAXC0',
#   'B01BNXI60I',
#   'B003HEUFNS',
#   'B000GLRREU',
#   'B005HRT0U2',
#   'B000FOI48G',
#   'B00YQBYO1K',
#   'B01B3E5IK8'],
#  'A232IJ75I4KP9C': ['B0189NOD4I',
#   'B01CXO7IYQ',
#   'B00XL2EB7M',
#   'B000GW78MU',
#   'B00CHH9KLO',
#   'B000FOI48G',
#   'B001QY8QXM',
#   'B00RFE2W5A',
#   'B00L1I1VMG',
#   'B000FOI48G'],
#  'A23GTKDW92ZPP2': ['B01DM261K0',
#   'B005M2C6PS',
#   'B00S1STS3I',
#   '1620213982',
#   'B01456S0YC',
#   'B0112164X2',
#   'B00CUG25FU',
#   'B000FOI48G',
#   'B00UXRQK1I',
#   'B00JVU3K9I'],
#  'A23O1B8IVSYKMO': ['B00LGLLY7K',
#   'B01D4XV9NQ',
#   'B01FDUJQIS',
#   'B00IPVCCVQ',
#   'B00BMVV3MK',
#   'B00FXTE88S',
#   'B013W4YFTW',
#   'B005HRT0U2',
#   'B00VYJVHO4',
#   'B003FZGQFK'],
#  'A23VR3KT0TPG83': ['B01DUF3EMC',
#   'B0189NOD4I',
#   'B00K1NKYM0',
#   'B00VF344X0',
#   'B00C4207LY',
#   'B00F4E23HA',
#   'B00QBZ7D9E',
#   '1620213982',
#   'B003I5VN7I',
#   'B000068PBJ'],
#  'A24HCM5QV0ZTJ5': ['B019169I1U',
#   'B00XLE44Y0',
#   'B0040AU5W4',
#   'B00ME2DGYO',
#   '1620213982',
#   'B00MGK9Z8U',
#   'B018ETY3J2',
#   'B0012Y0ZG2',
#   'B000050FDY',
#   'B000FOI48G'],
#  'A24ZE4O3OQMSP0': ['B00120VWTK',
#   'B01CXO7IYQ',
#   'B0189NOD4I',
#   'B013GX0LT2',
#   'B006IB5T4W',
#   'B0017I8Z6K',
#   'B003983HRI',
#   'B00OZQR05I',
#   'B00FXTE88S',
#   'B00763M03O'],
#  'A255E6ZWUBMEJJ': ['B000OV40LA',
#   'B00JKCYIV6',
#   '1620213982',
#   'B0049BAPBA',
#   'B00Z2AA0EO',
#   'B0067F28ZW',
#   'B006IB5T4W',
#   'B00J9PDIOW',
#   'B01DDQXRWU',
#   'B006VS7VJ8'],
#  'A258D00BRNHJ77': ['B000VV1YOY',
#   'B000FEF1V4',
#   'B000FOI48G',
#   'B000VR9PQC',
#   'B00S0PZNKE',
#   'B00LITWQ1I',
#   'B00BMVV3MK',
#   'B00OOEAC1K',
#   'B011JG1K3E',
#   'B00AWECYYO'],
#  'A25TLD8KIU807H': ['B000GLRREU',
#   'B00BHB5EEI',
#   'B0184M7AXA',
#   'B000GLRREU',
#   'B005EQOLAA',
#   '1620213982',
#   'B00K08QQOQ',
#   'B013VSOA7G',
#   'B002RZZXYE',
#   'B0006M559S'],
#  'A26434CRUTADT5': ['B00VY5W67K',
#   'B00JZ5F5Z6',
#   'B00592MMPA',
#   'B008U1Q4DI',
#   'B00021DJ32',
#   'B001QY8QXM',
#   'B006IB5T4W',
#   'B00Y40YTPY',
#   'B00TZ8XK1E',
#   'B018AVVYAK'],
#  'A26AT96096UOEZ': ['B00B697AUW',
#   'B0002DU57I',
#   'B000XVTYS0',
#   'B00NV6A3P2',
#   'B000FOI48G',
#   'B017KTAK0I',
#   'B015HIVIRI',
#   'B001QY8QXM',
#   'B00F029PWC',
#   'B00MY6FBJS'],
#  'A26RKZDM4DK8OQ': ['B00YA3DSNY',
#   'B00VKEPCBC',
#   'B000NCTTGG',
#   'B001JKRNX2',
#   'B0010DMNFQ',
#   'B004MBJL58',
#   'B00E60WYG8',
#   'B0099S7WM8',
#   'B00HA9ET7E',
#   'B0050NX23O'],
#  'A274IW68565M0U': ['B0057EVRHO',
#   'B015NA50DS',
#   'B002UNE5OM',
#   'B00CZH3K1C',
#   'B00Q794RMA',
#   'B004Z5H0XG',
#   'B0014SQQ3M',
#   'B015QSOGC8',
#   'B000FOI48G',
#   'B019DWCJDG'],
#  'A286OWYO1BDT52': ['B0009ZGK5K',
#   'B017HWK2BU',
#   'B000068PBJ',
#   'B00S81E1XK',
#   'B000FOI48G',
#   'B0168SXRR0',
#   'B00JLQKFZE',
#   'B00BMVV3MK',
#   'B00VKEPCBC',
#   'B00MNAE4UM'],
#  'A288UAQLON8FK2': ['B00P1J81Z6',
#   'B0091OCA86',
#   'B001HYO65S',
#   'B007KXO7LS',
#   'B0136SPLRE',
#   'B00ZKALN1U',
#   'B00M0YZ89W',
#   'B0188YXD5I',
#   'B01DGWYQCG',
#   'B01DKQAXC0'],
#  'A28E3FNV1BYC94': ['B01F6XBNWY',
#   'B0006M56BK',
#   'B0061DJC90',
#   'B01BVRP8PC',
#   'B003Y3PMXU',
#   'B000TBZAB4',
#   'B00K08QQOQ',
#   'B00QFHQUCO',
#   'B01DISEDP8',
#   'B018IAF9S6'],
#  'A28GO11F387SOX': ['B00021DJ32',
#   'B008YQM4A6',
#   'B004MXRMFM',
#   'B0013YXQ58',
#   'B00IG0RLVM',
#   'B000NCTTGG',
#   'B00JVU3K9I',
#   'B00QCVBRXU',
#   'B01EJ8JA6I',
#   'B0009MFUOU'],
#  'A28H0PFALTML0I': ['B00IAZSG5S',
#   'B00KQ12A0G',
#   'B002BX3PPG',
#   'B0070Z6Y2G',
#   'B01CX5KCIE',
#   'B001E6OCAI',
#   'B0015T1D24',
#   'B00TZ8XK1E',
#   'B004DPDSHU',
#   'B0059LBY3M'],
#  'A28OZKV4ZYZX42': ['B013VBXKDI',
#   'B01DKQAXC0',
#   'B01DMS5AYC',
#   'B00HY7S61W',
#   'B000FQMMWI',
#   'B00NSW0LGK',
#   'B000GLRREU',
#   'B00KOCGB5M',
#   'B007IDQ2SG',
#   'B00GMCP5NC'],
#  'A28P7FF1TVPG1K': ['B000WYJTZG',
#   'B000050FDY',
#   'B00BMW24TU',
#   'B00BMVV3MK',
#   'B01AHXKPEA',
#   'B00EBCS3TS',
#   'B00S8PHKI4',
#   'B000FOI48G',
#   'B015DLI7IM',
#   'B011JG1K3E'],
#  'A28Q7C1FAIZGLV': ['B00664875Y',
#   'B016V8YWBC',
#   'B017CHORY8',
#   'B01DKQAXC0',
#   'B000NKJIXM',
#   'B01HBSH2EK',
#   'B00427UY8K',
#   'B01DJ3WITA',
#   'B002DHVAZW',
#   'B001P4ZO4C'],
#  'A29834GBB4DOP1': ['B00LBPMBKA',
#   'B01FQIPOGA',
#   'B002DHVAZW',
#   'B0014C31JA',
#   'B00EWUFETQ',
#   'B00OXDWFG2',
#   '1620213982',
#   'B0012Y0ZG2',
#   'B01DQ29BBM',
#   'B00JVU3K9I'],
#  'A29HQ60YC1RG1P': ['B00005JS5C',
#   'B000FTYALG',
#   'B000FEGUIW',
#   'B00OXDWFG2',
#   'B006IB5T4W',
#   'B00PVZUSZ6',
#   'B01GO2E56W',
#   'B00KXDECGC',
#   'B01EN0FICW',
#   'B01DKQAXC0'],
#  'A29MENRU87PET0': ['B0070IAT38',
#   'B01AW4DMLM',
#   'B006FJ6BBM',
#   'B01D54YO3G',
#   'B014Q96T8W',
#   'B0020Z31S6',
#   'B002NEL6DG',
#   'B01CRSWZAU',
#   'B00Y7CYBUW',
#   'B00UL4GGGC'],
#  'A29PZKXDCQFTYW': ['B0067F28ZW',
#   'B01GR4IGSU',
#   'B009JKJ69I',
#   'B00TUAMC4S',
#   'B000GULSL4',
#   'B000URXP6E',
#   'B000PARERW',
#   'B001E0C9LI',
#   'B000PY9WSC',
#   'B00LR1H9G4'],
#  'A29SD3TFGX6Q34': ['B00WJXTTLM',
#   'B000FOI48G',
#   'B00IVJVFKG',
#   'B01CQ6VSI8',
#   'B012GA0UTW',
#   'B00O3092KW',
#   'B000VV1YOY',
#   'B01EGH00J8',
#   'B01B5CU4BG',
#   'B001AJ8YGC'],
#  'A2A0MIOWIW2SB8': ['B00T3OF7I4',
#   'B001AS5PV0',
#   'B00BMVV3MK',
#   'B011SDOZJ4',
#   'B00V7Q76XU',
#   'B01FL6ORN8',
#   'B015CAPB0G',
#   'B00M16MHHA',
#   'B00HA1FS3Q',
#   'B00N57PFYG'],
#  'A2A8ECI6ABJBMA': ['B01CNLMWE0',
#   'B018LYWD2Y',
#   'B01EY46Y0W',
#   'B000HGJLL6',
#   'B0067F28ZW',
#   'B01DKQAXC0',
#   'B00NW59IM6',
#   'B000FOI48G',
#   'B00021DJ32',
#   'B0185DYUCM'],
#  'A2AAQWBJJTK3E1': ['B01GFAO798',
#   'B00YQBYO1K',
#   'B00OLJ9DNG',
#   'B00SQ3S6TA',
#   'B00P7I0F3M',
#   'B000EE9XYG',
#   'B015WUR9NS',
#   'B000B9UUBO',
#   'B001KAAFRW',
#   'B00W7U1208'],
#  'A2AE0E0H463YL6': ['B00NT0AR7E',
#   'B005Y29IFM',
#   'B000WYJTZG',
#   'B002VZEI82',
#   'B01EMTIJES',
#   'B000EG8HLE',
#   'B0147J9S84',
#   'B001F51VVQ',
#   'B01E6NITSG',
#   'B010V6KKT8'],
#  'A2APG6OZXU4QIZ': ['B00R24HVDQ',
#   'B004Z9O8TG',
#   'B0014SQQ3M',
#   'B018KWPT6Y',
#   'B01F328PXS',
#   'B00005JS5C',
#   'B00OIQ4OFO',
#   'B01E76L01U',
#   'B000MT1GHA',
#   'B000WYJTZG'],
#  'A2BDB427ROEP7H': ['B00FIUEIY6',
#   'B000Q6HBIW',
#   'B017L0B1TA',
#   'B002OITLG0',
#   'B001V9FPHM',
#   'B01G29C9VA',
#   'B016I2W7E0',
#   'B001ET6XI4',
#   'B0070IAT38',
#   'B001QY8QXM'],
#  'A2BHJO8WOGMW6E': ['B00BMVV3MK',
#   'B001A3E5P2',
#   'B002P0ST1K',
#   'B00016WU6A',
#   'B000GLRREU',
#   '1620213982',
#   'B00ZO5YUQQ',
#   'B00CM0S5WQ',
#   'B00YMMOHU6',
#   'B01E7UKR38'],
#  'A2BOSA30FCF6G8': ['B01CSYNN7W',
#   'B011773GBE',
#   'B001J8SL3A',
#   'B0058H0GA4',
#   'B0142EAQ0I',
#   'B0012615W8',
#   'B01C8ENZNY',
#   'B0067F28ZW',
#   'B01CBB3020',
#   'B015Q8AM26'],
#  'A2BU6N5956T9NH': ['B00TKH9O0Q',
#   'B006WYJM8Y',
#   'B00GE5GLQC',
#   'B00PX1R0OU',
#   'B016I7RGDC',
#   'B005Y0AZXI',
#   'B00Y40YTPY',
#   'B005HI7KXA',
#   'B0010ZBORW',
#   'B00RVNUPXQ'],
#  'A2BUZ308P92OYA': ['B01G6YN23U',
#   'B00J3WDBCK',
#   'B01G17BLR6',
#   'B004BD9152',
#   'B018WCT01C',
#   'B019FWRG3C',
#   'B00622H60M',
#   'B017UPY1BQ',
#   'B001BROT1M',
#   'B019N8VZSU'],
#  'A2C1F859F9V1SL': ['B00005JS5C',
#   'B00Q794RMA',
#   'B00TYBQTF6',
#   'B019LBMXBM',
#   'B00MGK9Z8U',
#   'B000X2FPXC',
#   'B001QY8QXM',
#   'B01C2B3CFO',
#   'B0043QNR2K',
#   '1620213982'],
#  'A2C8YINPNRQOAU': ['B000GLRREU',
#   'B008E0DBYA',
#   'B01BRVADG6',
#   'B00UUIYH5Q',
#   'B0171BTD8U',
#   'B0191JMIO6',
#   'B00Y09GR6S',
#   'B014DH4FTC',
#   'B00VJZT4X4',
#   'B003983HRI'],
#  'A2CDQOF7WHUYKJ': ['B01AAVIO38',
#   'B007152FXW',
#   'B00SQ3S6TA',
#   'B00009RB1C',
#   'B013USRGFU',
#   'B006VS7VJ8',
#   'B00A2WF0D8',
#   'B00HPS7JC2',
#   'B00RMKY41W',
#   'B009PIJV1W'],
#  'A2CEEE0IK3LKN1': ['B01B5CU4BG',
#   'B00Q794RMA',
#   'B000GGKPXK',
#   'B0015TG1JE',
#   'B0067F28ZW',
#   'B00028LYO6',
#   'B00IIZG80U',
#   'B01FWP41H0',
#   'B00MGK9Z8U',
#   'B000FOI48G'],
#  'A2CZVE6ORV87C5': ['B000BJ1CGQ',
#   'B0054H0NZ6',
#   'B000GLRREU',
#   'B00W259T7G',
#   'B001YI92AQ',
#   'B007K6LID0',
#   'B01CL2UJY6',
#   'B01GIAO0VA',
#   'B000VV1YOY',
#   'B017W86R86'],
#  'A2DD6RH1AF0PLI': ['1620213982',
#   'B00KO2C3ZO',
#   'B01C7TTKLQ',
#   'B0012Y0ZG2',
#   'B01DOVXRJC',
#   'B01EB0DWHC',
#   'B001E96P6O',
#   'B00BY8AGHE',
#   'B01EDDAGH6',
#   'B00BMW24TU'],
#  'A2DFOCWUKJX3PT': ['B003VUOBJC',
#   'B00VF344X0',
#   'B00W259T7G',
#   'B000FKHX78',
#   'B003RC3ZSC',
#   'B00L88S190',
#   'B00OLMCLLE',
#   'B01131R3DQ',
#   'B01FVX9H90',
#   'B01AM3TGY0'],
#  'A2E8WG5GRZGMXU': ['B005PWE9PA',
#   'B01B694IOW',
#   'B000GLRREU',
#   'B01E5GSPWE',
#   'B000E0IO18',
#   'B0050RIN98',
#   'B01DA588BO',
#   'B00E1E1ZC8',
#   'B00JE09N9Q',
#   'B007AUWRWW'],
#  'A2ESQAPIGR2TJF': ['B017M402PO',
#   'B006IB5T4W',
#   'B01EHRVU4Q',
#   'B00VQHFBBE',
#   'B00TA30HK6',
#   'B00JIESMR2',
#   'B000MATKPO',
#   'B015HJ1IAO',
#   'B000EG8HLE',
#   'B01ES3OTCO'],
#  'A2EUQ4ESAB2N6A': ['B000EG8HLE',
#   'B01DL8XFNG',
#   'B00BQGYBO8',
#   'B00W259T7G',
#   'B00LIFGXLQ',
#   '0992916305',
#   'B0009RF9DW',
#   'B00NFVDN50',
#   'B00HYCWWNK',
#   'B0042TNAV6'],
#  'A2EZXF5YGYTOWN': ['B0067F28ZW',
#   'B000FOI48G',
#   'B001ADOW50',
#   'B00W2DHFNS',
#   'B0006M56BK',
#   'B018K6GHZC',
#   'B00FJ62DAA',
#   '1620213982',
#   '1620213982',
#   'B000FED5DU'],
#  'A2F0VQQLSF558D': ['B001FB5LV6',
#   'B0006M56BK',
#   'B016QSRYR6',
#   'B0016BFK2U',
#   'B000FED5D0',
#   'B00G3CY2PI',
#   'B01ECILOFU',
#   'B01H8RGVI2',
#   'B000256MZA',
#   'B01GI2F2SI'],
#  'A2F3QV40SONN60': ['B0174MNPNU',
#   'B0060P7J5S',
#   'B001QY8QXM',
#   'B000KNELAW',
#   'B00UTRTTYM',
#   'B00BMVV3MK',
#   'B002830ZD4',
#   'B000WYJTZG',
#   'B008ORT4NU',
#   'B000FOI48G'],
#  'A2F95NSPD4XEEU': ['B008U1Q4DI',
#   'B00FQI9HYG',
#   'B01FIQ0TNI',
#   'B0013NB7DW',
#   'B000FED5DU',
#   'B000FOI48G',
#   'B017JR0P3S',
#   'B017447GGA',
#   'B00YMMOHU6',
#   'B019D1XQ4S'],
#  'A2FA2J1JT12N7J': ['B00517W5LY',
#   'B00H71UXFC',
#   'B00PYFR9PK',
#   'B000FOI48G',
#   'B000TQG4P0',
#   'B006IB5T4W',
#   'B01G4AO3NY',
#   'B0009YDO46',
#   'B004VGIA60',
#   'B0010ZBORW'],
#  'A2FFUJ5D4CMJ4L': ['B01AWXGD3M',
#   'B000GLRREU',
#   'B0057N3TPS',
#   'B0013NB7DW',
#   'B000GLRREU',
#   'B008EJJ50A',
#   'B000LCETUO',
#   'B00C9SRP54',
#   'B00DQVV5XQ',
#   'B01EWU9DCE'],
#  'A2FLLYV6Z8UQ26': ['B00JVU3K9I',
#   'B000GLRREU',
#   'B002K4NP1U',
#   'B000050FDY',
#   'B00PEFM5MC',
#   'B014N7WP5S',
#   'B00ZRV9PQ2',
#   'B01H5ZYTMC',
#   'B00TKN6A02',
#   'B01H5ZYTMC'],
#  'A2G1XJ25DR7PVF': ['B00005JS5C',
#   'B01FLJROJ4',
#   'B0191NQQOA',
#   'B000PARERW',
#   'B001LOJ2BW',
#   'B017CHORY8',
#   'B00JY0PHJQ',
#   'B00ZGVT2Q6',
#   'B00HID2N9I',
#   'B006IB5T4W'],
#  'A2G5KJ0CZE65ZD': ['1620213982',
#   'B000MAESRE',
#   'B0014SQQ3M',
#   'B000GLRREU',
#   'B000FOI48G',
#   'B0091OCA86',
#   'B019R7KEPC',
#   'B002K5SWA8',
#   'B00GIX8ULE',
#   'B0166R22CO'],
#  'A2GFPTQ4VWDX96': ['B000FOI48G',
#   'B000WNWW7Y',
#   'B015JDMF9G',
#   'B001TSMPUA',
#   'B01F3SWCOU',
#   'B0015S8026',
#   'B01GPOM4IK',
#   'B01GW09XRW',
#   'B0191DBE2E',
#   'B013G939TU'],
#  'A2GJLNRQTVUNOF': ['B006IB5T4W',
#   'B006IB5T4W',
#   'B01C4ZAPGM',
#   'B01HHZFF32',
#   'B00B0SA1SC',
#   'B01CBANZKI',
#   'B01CSC6WG8',
#   'B00B46UFD6',
#   '1620213982',
#   'B01H3ZQ2NI'],
#  'A2GOFJ3OZZUZ3H': ['B00K2GF7SC',
#   'B00I6Q1WP2',
#   'B00HUHFRBS',
#   '0143026860',
#   'B000JIPKLM',
#   'B0017TZD7S',
#   'B001P5HCKK',
#   'B01DKQAXC0',
#   'B01E5ZJIEY',
#   'B01DH9NS2C'],
#  'A2GV0FE30O6M67': ['B01DKQAXC0',
#   'B00TUDHZ5Q',
#   'B013RJY9A2',
#   'B009SNB978',
#   'B005C18UTK',
#   'B00YO55LJC',
#   'B00IPV2LPI',
#   'B00009RB1C',
#   'B00VF344X0',
#   'B001QY8QXM'],
#  'A2H3W11661MWDA': ['B01B18T01Y',
#   'B00592MMPA',
#   'B00LF9W5PI',
#   'B0001TMDF0',
#   'B00AM3YG2I',
#   'B000BKXGXW',
#   'B000H6A02A',
#   'B002NEL6DG',
#   'B00B9H45JU',
#   'B017WTVQI6'],
#  'A2H7FD5GQMJXAQ': ['B006WYJM8Y',
#   'B00BMVV3MK',
#   'B00MGK9Z8U',
#   'B001MP0QBU',
#   'B0012XPRO8',
#   'B00B7V273E',
#   'B00CF21G2W',
#   'B00J3WDBCK',
#   'B018IX2RE2',
#   'B01D8030L4'],
#  'A2H7VSYLKGKLLJ': ['B000GLRREU',
#   'B006IB5T4W',
#   'B01ERKE0ZO',
#   'B0018OVL4G',
#   'B00WIKHV1Q',
#   'B010TQC4R6',
#   'B01FVSIOZI',
#   'B00Y40YTPY',
#   'B00C6CCD8C',
#   'B01D85U00S'],
#  'A2HFAX39PMLIGH': ['B0017TZD7S',
#   'B00X3T6FEU',
#   'B008CLINIA',
#   'B00PHMM3LK',
#   'B01FQRYIDQ',
#   'B0175PT3KK',
#   '1620213982',
#   'B00J3WDBES',
#   'B000GLRREU',
#   'B005GMY86O'],
#  'A2I4O72AAE1T1T': ['B01AL9W2TG',
#   'B01CX5KCIE',
#   'B000VV1YOY',
#   'B01E5ZJIEY',
#   'B00642LI90',
#   'B0010ZBORW',
#   'B01H3KUIY2',
#   'B000W9IWMM',
#   'B017M402PO',
#   'B00005JS5C'],
#  'A2I868XUY96VWA': ['B00BMVV3MK',
#   'B01DBML2DC',
#   'B01BUP23IK',
#   'B015HSTGRW',
#   'B00GBYNAJM',
#   'B007UHY8IG',
#   'B016M4A7OQ',
#   'B000050FDY',
#   'B000FQMMY6',
#   'B000050FDY'],
#  'A2IK039KMC8UP1': ['B00MI4F2LS',
#   'B00NOFU1IY',
#   'B000EE9XYG',
#   'B00INY7VI4',
#   'B01B54XW54',
#   'B004SJZ0DG',
#   'B009Z4NLB2',
#   'B00070D21W',
#   'B00U0EG3I4',
#   '1465045953'],
#  'A2IMJV0CQMZLGC': ['B002RTUK70',
#   'B019809F9Y',
#   'B000050FDY',
#   'B00IMQFTDM',
#   'B00Q794RMA',
#   'B006L44UA0',
#   'B001E5PLCM',
#   'B004C31MSK',
#   'B00F8HWJ2M',
#   'B00H1M8R3C'],
#  'A2INWR0T7A7UN5': ['B00VKEPCBC',
#   'B00W259T7G',
#   'B00021KD2C',
#   'B00LH2JX80',
#   'B000NQ6PJ6',
#   'B014JOHYD8',
#   'B00GXD27OK',
#   'B00S1NC4BG',
#   'B0006NY1NS',
#   'B00NOFU1IY'],
#  'A2IOBG1ERS4JP3': ['B00C3WPMBK',
#   'B011773O2U',
#   'B00YQBYO1K',
#   'B00PKXL10U',
#   'B0189CM3U0',
#   'B0175PT3KK',
#   'B001FB5H9C',
#   'B00G03YKGG',
#   'B01E0OPMVI',
#   'B00W259T7G'],
#  'A2IRPQ7DXQ9YIN': ['B000FOI48G',
#   'B00AV8LR4E',
#   'B000GLRREU',
#   'B011JG1K3E',
#   'B01GR53BUC',
#   'B01H2DITZA',
#   'B0017TZD7S',
#   'B01H0TJCZM',
#   'B0189NOD4I',
#   'B019FB6NYG'],
#  'A2J4WOR87ELFBH': ['B013XKHA4M',
#   'B000TGEBVE',
#   'B01E9S00C6',
#   'B00QU76L4Q',
#   'B01DGWYQCG',
#   'B00CHJXA72',
#   'B00KHYHBZG',
#   'B01H640HTG',
#   'B0007OC0A2',
#   'B018KUODLS'],
#  'A2JCBLTLYDPQLW': ['B000FOI48G',
#   'B00009RB1C',
#   'B0119Q9FYU',
#   'B000FOI48G',
#   'B01DW0PLQM',
#   'B00W7U1208',
#   'B000067E30',
#   'B0001TMDF0',
#   'B000EG8HLE',
#   'B000FOI48G'],
#  'A2JEH2NKM1Z8CQ': ['B00YQBYO1K',
#   'B01E4DQ9VM',
#   'B00009RB1I',
#   'B00VC2FUXM',
#   'B00XOR9X1I',
#   'B01DKQAXC0',
#   'B00IIAK0RW',
#   'B01A8DBE3A',
#   'B00021DJ32',
#   'B0085RZLVS'],
#  'A2JXZSR7R85KX4': ['B00T9SZ6L2',
#   'B0175PT3KK',
#   'B00I3F4QSQ',
#   'B005M2C6PS',
#   'B015XAGFVO',
#   'B01ANDCN9E',
#   'B006GDB518',
#   'B00021KD2C',
#   'B01G53UOME',
#   'B00G5L867C'],
#  'A2K7XZCFYGZH0O': ['B01FDLAR7Q',
#   'B01B54XW54',
#   'B000052YMO',
#   'B00CKWZGIW',
#   'B001F51RAG',
#   'B00383Q2KI',
#   'B00UICO9FC',
#   'B0001HYKC6',
#   'B000GG7NU8',
#   'B004IQA3TU'],
#  'A2KO4HGLWB57LI': ['B00APPLSVA',
#   'B000GLRREU',
#   'B00DXMK1H4',
#   'B00EC9XKNY',
#   'B0050RIN98',
#   'B015DZXQKC',
#   'B01CGU3DXC',
#   'B00AJECD2A',
#   'B01DKQAXC0',
#   'B0015TF1ZO'],
#  'A2KVN4XKFJH0I8': ['B00J2QHKCO',
#   'B005IC4V8C',
#   'B005GMYQ52',
#   'B000W9IWMM',
#   'B00CPGIAC2',
#   'B000GI0X1C',
#   'B00SNXTLFQ',
#   'B00Z794FMS',
#   'B00J3G958K',
#   'B001AJD0UM'],
#  'A2LM47GK1W7RRR': ['B000GLRREU',
#   'B006WYJM8Y',
#   'B006W2SYHQ',
#   'B01DP8QD22',
#   'B00X3Q81SQ',
#   'B00IIZG80U',
#   'B00SUCA3HK',
#   'B000GLRREU',
#   'B00DEM0QVE',
#   'B005U5KU46'],
#  'A2LSOMD2X9KCCH': ['B01CH80FEI',
#   'B000GLRREU',
#   'B00JYGWWIO',
#   'B00NFEZYZY',
#   'B015YEZ7Z4',
#   'B01C39X6TW',
#   'B01HBDW9O8',
#   'B00NJ270ZY',
#   'B00D3D06HS',
#   'B01DBD728K'],
#  'A2LYTBRWFQJMKM': ['B00766SGPM',
#   'B01FHDYGQ8',
#   'B006U7NSO2',
#   'B0167J2FUU',
#   'B0000530HU',
#   'B00VCNKIAG',
#   '1620213982',
#   '1620213982',
#   'B00IIAK0RW',
#   'B00NV6LT5A'],
#  'A2M4YSOJZELJ6N': ['B009SNB978',
#   'B000GLRREU',
#   'B00LLLXEUA',
#   'B00JZ5FAK6',
#   'B01E3WVN9W',
#   'B000YB70PS',
#   'B00RD34E8G',
#   'B00J5K59P2',
#   'B00X918PRC',
#   'B00O74YTE8'],
#  'A2MAZK8XSIDXPF': ['B00LS6FEDI',
#   'B01DISEDP8',
#   'B01AJZ2A8K',
#   'B0136SPLRE',
#   'B002B5UVTW',
#   'B001Q2FMA4',
#   'B00ZIMJRC2',
#   'B008ORT4NU',
#   'B00NV64KUQ',
#   'B015N6GYR8'],
#  'A2MDIPJ7MS0MUJ': ['B00L5HZCPU',
#   'B000WYJTZG',
#   'B01EF64LIG',
#   'B001OHV1H4',
#   'B010PG5XFU',
#   'B0001XQNPW',
#   'B00CCJDF1S',
#   'B000GLRREU',
#   'B00592MMPA',
#   'B00KJ0PZCO'],
#  'A2MGO3WV3SX7X': ['B000FOI48G',
#   'B00YQTQ9I8',
#   'B000E3FEC2',
#   'B00AUB5SII',
#   'B00FOGYACO',
#   'B000WYJTZG',
#   'B00BEE4FQ6',
#   'B00L0JYAZG',
#   'B01FY36NUS',
#   'B01GO2E4EA'],
#  'A2MLV3I5MMJ2RA': ['B01AIXBRZK',
#   'B00005JS5C',
#   'B00MY6FBJS',
#   'B01BI4O5IY',
#   'B01BPTV2TC',
#   'B000PKNPES',
#   'B00W259T7G',
#   'B00L88S190',
#   'B000H6A02A',
#   'B004N7B4IS'],
#  'A2MPSHMC0U29AV': ['B016QSRYR6',
#   'B00U1WTSI2',
#   'B00XJFIBJU',
#   'B01E7UKR38',
#   'B01GLA54SA',
#   'B00G5L867C',
#   'B000EG8HLE',
#   'B000GCOIMI',
#   'B005FYE6VU',
#   'B00EBZD0PW'],
#  'A2NI47L1B1RXSG': ['B010PJX8UE',
#   'B0013NB7DW',
#   'B000NV7U5E',
#   'B001E0Y5YM',
#   'B006FLRZ5G',
#   'B00OB70BR0',
#   'B00CR6X0IY',
#   'B000M9YKPK',
#   'B00VKEPCBC',
#   'B009I8VR7K'],
#  'A2NJQZBE8TSUYO': ['B019ZZ1DVK',
#   'B00P3AF3QS',
#   'B00WVCQ8RO',
#   'B001J7Q458',
#   'B000EGMBO8',
#   'B00H2S84EM',
#   'B00I2O4GOW',
#   'B00K0KAQJA',
#   'B01BT28GXA',
#   'B000FOI48G'],
#  'A2NWTETCSLOEQN': ['B00M7VQ61M',
#   'B000KNELAW',
#   'B00766SGPM',
#   'B000YB70PS',
#   'B001DCJ7OY',
#   'B00D8FUHFC',
#   'B01EWW45QG',
#   'B01B6SLUYE',
#   'B01E0C1XEK',
#   'B007QX2KLG'],
#  'A2O4DMC8M5JFHG': ['B0009WY5AA',
# ...
#   'B00028LYO6',
#   '1620213982',
#   'B01DLBWFVQ',
#   'B001MW1MK2',
#   'B00BMVV3MK',
#   'B011773O2U',
#   'B00XLXMJE8',
#   'B00ARBOMTM',
#   'B001AMRQ2W'],
#  'AD9O852KPYLHY': ['B00YQTQ9I8',
#   'B000EPUQKK',
#   'B00TYBQTF6',
#   'B01GQ85WAC',
#   'B001F51RAG',
#   'B010WSP5NQ',
#   '1620213982',
#   'B00KBEQYGE',
#   'B00PQJD4MG',
#   'B00VF344X0'],
#  'ADDXT6NXD9GQ7': ['B007JUIBMI',
#   'B001QY8QXM',
#   'B010SV3L3I',
#   'B019R7KEPC',
#   'B010B5ZE4U',
#   'B01EST7TBQ',
#   'B00IF7QF1S',
#   'B0043RL0SC',
#   'B013BW8JT2',
#   'B004PLIH5U'],
#  'ADG8D8X6P9X7M': ['B00X1JWQU4',
#   'B000050B6B',
#   'B0014BB6WA',
#   'B00CFDBOKA',
#   'B01D9W51KY',
#   'B00190PJBK',
#   'B00NNLYTFU',
#   'B00OIQ4OFO',
#   'B01FDLAR7Q',
#   'B007FAOQF8'],
#  'ADR4IE33O06IJ': ['1620213982',
#   'B01B6YTFRC',
#   'B015DZXQKC',
#   'B000FOI48G',
#   'B002O2JXWS',
#   'B0058H0GA4',
#   'B00028LYO6',
#   'B00HYCWWNK',
#   'B002BFPBZQ',
#   'B001TQO3B6'],
#  'ADV1MNMPVS17V': ['B000VV1YOY',
#   'B00EP1N77I',
#   'B00H1Q4VZQ',
#   'B0026DE7NK',
#   'B00OR1D37A',
#   'B00AB0O8SE',
#   'B0018OVL4G',
#   'B00FW6MJ6K',
#   'B01CUXUOIC',
#   'B007HERMKI'],
#  'ADYRHTPM2T2SE': ['B000OV40LA',
#   'B00KVMV0QA',
#   'B00COGVXNQ',
#   'B01FQRYIDQ',
#   'B007XA2T9U',
#   'B00006L9LC',
#   'B00UWB35UY',
#   'B001AJ6YS2',
#   'B01AVFO3TM',
#   'B00261080I'],
#  'AE6VHWVRXHU19': ['B001AMRQ2W',
#   'B00N0CRKMQ',
#   'B000EG8HLE',
#   'B000EG8HLE',
#   'B006FLRZ5G',
#   'B01G5ICP7Q',
#   'B000H6A02A',
#   'B00DN9V644',
#   'B000GLRREU',
#   'B01E7HRX2Y'],
#  'AEKJTREHL41OE': ['B00GHJOM2U',
#   'B000EE9XYG',
#   'B01FS8XZVO',
#   'B000FOI48G',
#   'B000WZHGVY',
#   'B000FOI48G',
#   'B00399D3Y4',
#   'B001QY8QXM',
#   'B0009MFUOA',
#   'B01H7TWVS0'],
#  'AEP7KPEZWI7VY': ['B000FED5D0',
#   'B01DWZOQXQ',
#   'B00K8OE0PO',
#   'B01DKQAXC0',
#   'B00IUI0QFS',
#   'B00M7BX9KI',
#   'B000GLRREU',
#   'B00BMVV3MK',
#   'B004EFECYC',
#   'B0043R528G'],
#  'AETOYW0R5VN0X': ['B0119Q9FYU',
#   'B019E73XNK',
#   'B01ATY94XK',
#   'B01G8KISJU',
#   'B00G3CY2PI',
#   'B008O0ZTPO',
#   'B001AJ8YGC',
#   'B00IPVCCVQ',
#   'B019EUWONW',
#   'B00KRT4HBW'],
#  'AEZBSOFLB44RG': ['B018UJEFOE',
#   'B01B54XW54',
#   'B00OR1D37A',
#   'B00011QUDE',
#   'B001QY8QXM',
#   'B00CQARQZO',
#   'B00W259T7G',
#   'B000FED5DU',
#   'B000FOI48G',
#   'B013H5EM6W'],
#  'AFE9H6ABXM735': ['B01DFHDMS6',
#   'B00PHMM3LK',
#   'B01FSNSJOM',
#   'B01H3HPFSE',
#   'B0001TMDF0',
#   'B01E1DOTMG',
#   'B0013NBVV0',
#   'B00020UR4C',
#   'B01GR3AU12',
#   'B015HL3XWI'],
#  'AFMQ7BBR4FYMB': ['B000MN4J84',
#   'B001V9DHHM',
#   'B00XLE44Y0',
#   'B01CRSWZAU',
#   'B00CQ16CT4',
#   'B0006NYERQ',
#   'B017WJ3R9C',
#   'B00NFUYDH8',
#   'B00VXEWBJK',
#   'B00G5L867C'],
#  'AFY8EIWAT6H8J': ['B00NB0QCQW',
#   'B00OTG3H1K',
#   'B000W0C07Y',
#   'B00PEVQ5J0',
#   'B00AQXD2HO',
#   'B00TA30HK6',
#   'B0070Z6Y2G',
#   'B00120VWTK',
#   'B000050FDY',
#   'B00R3LPI5Q'],
#  'AG0867QGE3R2B': ['B004SBJBNO',
#   'B000GZJIVQ',
#   'B00ICQV260',
#   'B000EG8HLE',
#   'B01D1U5PNC',
#   'B0179GD5CC',
#   'B000GCVVWI',
#   'B01FY4WF54',
#   'B0091OCDRE',
#   'B01FTIQ18C'],
#  'AG3T3ILPXFL3H': ['B009XPCFAQ',
#   'B00FFVHZXE',
#   'B0054H0NZ6',
#   'B00MILQS00',
#   '1620213982',
#   'B00GQOTDZC',
#   'B01FGAECCA',
#   'B0099YJWN4',
#   'B000PJ82PQ',
#   'B006IB5T4W'],
#  'AG74ZKO3BG57J': ['B017BUXXKA',
#   'B000FED5DU',
#   'B00TRGN2Z8',
#   'B00NV5ZUKG',
#   'B000GLRREU',
#   'B00K08R11I',
#   'B00M970200',
#   'B00T8GRNKC',
#   'B00C6NZH3E',
#   'B019809F9Y'],
#  'AGORXWI6K2RIR': ['B00IN8FQJG',
#   'B00PZW2R54',
#   'B00MQKHE74',
#   'B000VV1YOY',
#   'B000VV1YOY',
#   'B00L1I1VMG',
#   'B013C7OR7O',
#   'B01BNK1PGI',
#   'B00R3OQP14',
#   'B00CHI49BE'],
#  'AGRZQOBCF8H87': ['B00009RB1C',
#   'B001QY8QXM',
#   'B0018OVL4G',
#   'B008O0ZTPO',
#   'B007SA3AUW',
#   'B015OBICRM',
#   'B00P0BODX4',
#   'B017JXH2QK',
#   'B00UKDRPVY',
#   'B0018OVL4G'],
#  'AGTD0T9R78YLG': ['B0000YVACI',
#   'B000EE9XYG',
#   'B01GNP27AG',
#   'B00KLGCW6I',
#   'B006IB5T4W',
#   'B019OQRUYE',
#   'B000GLRREU',
#   'B00ZYYCJ8I',
#   'B0006O10P4',
#   'B01HC6G4D6'],
#  'AGYIYIVZHBI60': ['B00M8RRQQ4',
#   'B01H640HTG',
#   'B0194BW6KC',
#   'B01CBANZKI',
#   'B002OITLG0',
#   'B000LCETUO',
#   'B001OHV1H4',
#   'B0051S94NA',
#   'B000GLRREU',
#   'B000FOI48G'],
#  'AHGNU4UWGATOH': ['B00QHX7NT0',
#   'B00F1WC4RO',
#   'B01DFHDMS6',
#   'B0017TZD7S',
#   'B00BMW24TU',
#   'B01BK2IH38',
#   'B0020Z31S6',
#   'B014QUW8EK',
#   'B00LH05BDS',
#   'B01DYUYATO'],
#  'AHYRXYR235TWH': ['B00FZNKH32',
#   'B002EF0FAE',
#   'B007K6LID0',
#   'B00NW5BWCK',
#   'B00TLL1JZ4',
#   'B0067F28ZW',
#   'B01DKQAXC0',
#   'B00CCG7UZS',
#   'B00IYSQIPG',
#   'B004UTSRNY'],
#  'AIB7HX2UC3WHM': ['B00TKRTPPA',
#   'B01DBD728K',
#   'B000FOI48G',
#   'B0195R1FT8',
#   'B000FOI48G',
#   'B006BKZ4O0',
#   'B000050FDY',
#   'B001QY8QXM',
#   'B01DU6WN3C',
#   'B00OFMSBYG'],
#  'AITF34BGBMVJJ': ['B00V8293OS',
#   'B000A2LRBY',
#   'B00N0D0YCI',
#   'B00D8FUHFC',
#   'B000FI4S1E',
#   'B00VTPL7M0',
#   'B007QG7G3U',
#   'B00011QUDE',
#   'B006IB5T4W',
#   'B000EG8HLE'],
#  'AIU7HYQIC5D95': ['B00MGK9Z8U',
#   'B01DKI8S1Q',
#   'B000GLRREU',
#   'B019YH9INY',
#   'B00V6F0CJM',
#   'B000FOI48G',
#   'B00RGTAHU6',
#   'B00QAU4GKE',
#   'B00X5I2NL8',
#   'B001P2NRPC'],
#  'AJHSB0LT8NKP4': ['B00XDB3QTA',
#   'B000NSU25M',
#   'B00DQAZRZ4',
#   'B017U2Z8BG',
#   'B00PYFR9PK',
#   'B0001TMDF0',
#   'B01E7UKR38',
#   'B010SV3L3I',
#   'B008N1M588',
#   'B00NOFU1IY'],
#  'AJYMJEC6B7V52': ['B00VKEPCBC',
#   'B00QEHIJVU',
#   'B00JVU3K9I',
#   'B00CUG25FU',
#   'B000Z61POY',
#   'B000209JPU',
#   'B000PKKAFK',
#   'B001U1YTDC',
#   'B006IB5T4W',
#   'B000GLRREU'],
#  'AK4VANLR5UK95': ['B0002MQ9GK',
#   'B01092DRWG',
#   'B01BV3LHLK',
#   'B0140TEQDI',
#   'B000G8LWZI',
#   'B0092D6L3Q',
#   'B000FQMMWI',
#   'B0195R1FT8',
#   'B000FOI48G',
#   'B0175PT3KK'],
#  'AK7YIZE6ZZ1N9': ['B00NV702XO',
#   'B0077P1DG6',
#   'B002BGQ9VA',
#   'B00LH4KHU6',
#   'B01GIAO0VA',
#   'B01ES3OTCO',
#   'B00FZERN3I',
#   'B000G8LWZI',
#   'B0013NB7DW',
#   'B01GCL654K'],
#  'AKHSKD91MQ9DP': ['B01C2B3CFO',
#   'B003FZGQFK',
#   'B00HNISNPQ',
#   'B01EA881MG',
#   'B008S1XBAE',
#   'B019RF59O0',
#   'B0043R6UIW',
#   'B015MT6Q7Y',
#   'B00IITJWOU',
#   'B01F3SWCOU'],
#  'ALUZH689LQE6K': ['B01BI52N5U',
#   'B000GLRREU',
#   'B00B6A5SZK',
#   'B00CW2K72A',
#   'B016WMO5I2',
#   'B007YT34TY',
#   'B00FIUEIY6',
#   'B002BTFQAW',
#   'B013VZRLB6',
#   'B00MJNMMX4'],
#  'ALWLZC3GRRXPN': ['B006IB5T4W',
#   'B0175PT3KK',
#   'B000GLRREU',
#   'B00OP8NZV4',
#   'B00GW58YC8',
#   'B00HWI6JA8',
#   'B00VJ4H6Y4',
#   'B017GK6F1Y',
#   'B01EJEA6IS',
#   'B0091OCA86'],
#  'AM1KUDVTKXIAQ': ['B00HMBN5PC',
#   'B01GIRN5OQ',
#   'B0145Q5OLY',
#   'B000FOI48G',
#   'B00BPOL5D6',
#   'B000FOI48G',
#   'B01DTQRPWW',
#   'B000FOI48G',
#   'B00T673WMQ',
#   'B005OS9U3G'],
#  'AM9HBLGAPZQR7': ['B001W3YQZO',
#   'B000WYJTZG',
#   'B0009MFUPY',
#   'B00KA8RKBO',
#   '1620213982',
#   'B000NCTTGG',
#   'B005JR4ZZ0',
#   'B00ZUIASZO',
#   'B01AAVIO38',
#   'B016UMQNZC'],
#  'AMA98TY969A1T': ['B001BOKR3E',
#   'B01DKQAXC0',
#   'B019WWUY16',
#   'B01GQKM0AK',
#   'B000FI4S1E',
#   'B006JSJTG8',
#   'B01DH9NS2C',
#   'B000NVIFGW',
#   'B01DKQAXC0',
#   'B0007OC0A2'],
#  'AMLDY4QY4HV0D': ['B001AJ6YS2',
#   'B00JDZ3O2O',
#   'B01DKQAXC0',
#   'B00CDPX5UC',
#   'B01BPGD8TW',
#   'B012YLE74M',
#   'B00PYFR9PK',
#   'B01DKQAXC0',
#   'B001AMRQ2W',
#   'B01G7TWQH2'],
#  'AMVZ9HW23Y42N': ['B01H3IVSAC',
#   'B0093A4P0Y',
#   'B000W9IWMM',
#   'B000MT1GHA',
#   'B000FELPIC',
#   'B01DNP9ILK',
#   'B01B54XW54',
#   'B007EITOSK',
#   'B009969F2K',
#   'B00W259T7G'],
#  'AN3QZR3OD7SFO': ['B010SV3L3I',
#   'B000VUWZCU',
#   'B00MOUJMLC',
#   'B00FW6JXNM',
#   'B004EHHZY4',
#   'B00RCNHRQ8',
#   'B00W259T7G',
#   'B01GCLNY6C',
#   'B011AKOVGW',
#   'B00JCSLA6O'],
#  'ANC6FN6T8JBB2': ['B01DKQAXC0',
#   'B0176E2C62',
#   'B009JKJ69I',
#   'B000PARERW',
#   'B00GA9U1RC',
#   'B000FOI48G',
#   'B01BZV6VVY',
#   'B00MNALFMC',
#   'B004P7AXOW',
#   'B00HNK96UK'],
#  'ANDGVKQ15NCZM': ['B01D3RHAP4',
#   'B011AKOVGW',
#   'B011AKOVGW',
#   'B000FOI48G',
#   'B01G4AO3NY',
#   'B001TOAX4Y',
#   'B00SKXZI6K',
#   'B002NEL6DG',
#   'B018WCT01C',
#   'B010V6KKT8'],
#  'ANFUWUOC7EJKR': ['B002791OAC',
#   'B000IQXOPE',
#   'B00592MMPA',
#   'B001AJ6YS2',
#   'B00OQJL5FA',
#   'B00C9OU8U2',
#   'B007NIR2C6',
#   'B00IIZG80U',
#   'B00U1F7ABG',
#   'B00XOONVUA'],
#  'ANG7MOYBTWQE6': ['B01H2DXMAC',
#   'B000WYJTZG',
#   'B000EG8HLE',
#   'B01FDLAR7Q',
#   'B000068PBJ',
#   'B00PZW2R54',
#   'B0096MIQAE',
#   'B00KOCGB5M',
#   'B00WTBQRLO',
#   'B00567UTKI'],
#  'ANJ6Y9G0B4TM8': ['B000YB70PS',
#   'B00W259T7G',
#   'B00EYHM70G',
#   'B00009RB1C',
#   '1620213982',
#   'B000FOI48G',
#   'B00D8B11AQ',
#   'B00JRN8UVC',
#   'B01DKQAXC0',
#   'B000VV1YOY'],
#  'ANR73TPVBCQ9K': ['B004E3ION4',
#   'B003XS017S',
#   'B01BJCX44Q',
#   'B0186AH6VG',
#   'B01BHO3RLG',
#   'B016RCQ5AS',
#   'B00BMVV3MK',
#   'B01FTIQ18C',
#   'B000FOI48G',
#   'B00J5K59P2'],
#  'ANT034IX5ZPI9': ['B001II61K6',
#   'B00DDVAVN4',
#   'B00JBC9TD2',
#   'B00123MFFC',
#   'B005WXKLOA',
#   'B0058A4ZOE',
#   'B00W6FE3EG',
#   'B001AJD0UM',
#   'B00L62HMQG',
#   'B002G0WR08'],
#  'AOB2Y1KJQG7K7': ['B008YQM4A6',
#   'B01CTIJEIY',
#   'B001D0OSLS',
#   'B00HE0CB6A',
#   'B0194D91RG',
#   'B00IZLBCWQ',
#   'B00FDJSIL6',
#   'B001ET79AK',
#   'B008A0662I',
#   'B004KNJPBS'],
#  'AONHG4PDUQ0D6': ['B01D8030L4',
#   'B01DKQAXC0',
#   'B005ROU5U4',
#   'B01DKQAXC0',
#   'B01ADSQ1TM',
#   'B00DT4757A',
#   'B00OAMFI24',
#   'B00B6XTTL6',
#   'B001K80AYM',
#   'B000FOI48G'],
#  'APA9SALOTTBM6': ['B0086LC16Q',
#   'B016I2TLL2',
#   'B01G3B0SFG',
#   'B0119Q9FYU',
#   'B0067F28ZW',
#   'B0077P1DG6',
#   'B01EGH00J8',
#   'B00KQ3B0ZA',
#   'B00L0JYAZG',
#   'B00005JS5C'],
#  'APARJQGAD0J4C': ['B00PYFR9PK',
#   'B001J9R93W',
#   'B00FJPMNEM',
#   'B015ZTNN7W',
#   'B001HLDYRM',
#   'B0010DMNFQ',
#   'B01ENDFXJW',
#   'B00IXHBQ5U',
#   'B019EUWONW',
#   'B01FY36NUS'],
#  'AQ5PKYF0FJA4B': ['B006WYJM8Y',
#   'B000K10V2Q',
#   'B008E0DBYA',
#   'B00W259T7G',
#   'B01ATYTQP6',
#   'B00O1DY34G',
#   'B001OHV1H4',
#   'B005P0T7E0',
#   'B000GCLR40',
#   'B006JZ0IRA'],
#  'AQCQQYEUHUX3M': ['B00EP1N77I',
#   'B0006M56BK',
#   'B01E4DQ9VM',
#   'B006IB5T4W',
#   'B0018OVL4G',
#   'B00FTP8X0A',
#   'B000FOI48G',
#   'B000FOI48G',
#   'B000GLRREU',
#   'B000WN2T0Y'],
#  'AQYL4TDY2HU8Z': ['B00AFCOWJS',
#   'B00GW58YC8',
#   'B0175ZBLT6',
#   'B01GR3OXTM',
#   'B017GH7G5Q',
#   'B004LUQRJI',
#   'B017THCQQ2',
#   'B0006M56BK',
#   'B008U1Q4DI',
#   'B00M3X3ILU'],
#  'AR9Y0CM5B174': ['B00EWUFETQ',
#   'B000KNELAW',
#   'B000VUXCGI',
#   'B01CTQC9J2',
#   'B017JBTB98',
#   'B00XCC478E',
#   'B019EMVHBA',
#   'B000MT1GHA',
#   'B001QY8QXM',
#   'B00BY8AGHE'],
#  'ARLN791TA1RV7': ['B00TUAK3QW',
#   'B00NT0AR7E',
#   'B0010ZBORW',
#   'B000WNAB2M',
#   'B001AJD0UM',
#   'B00RN4XBNY',
#   'B004BC62MI',
#   'B00ECMPH5A',
#   'B00OTG3H1K',
#   'B011KSK8P2'],
#  'AS8T77HTF9IHW': ['B004EFECYC',
#   'B019X81S82',
#   'B018SFIGXG',
#   'B00X4DKZKU',
#   'B00GM331X2',
#   'B001P5HCKK',
#   'B00FACYJ8M',
#   'B00ZGRHKV4',
#   'B01CZSKZCM',
#   'B000FEGUIW'],
#  'ASGIVOW34XNQS': ['B000PKMA2G',
#   'B018TZ5MVE',
#   'B00M1YZWII',
#   'B000NQ6PJ6',
#   'B017BCQLMA',
#   'B000V2MBZ4',
#   'B00VF344X0',
#   'B00J54BUJC',
#   'B006IB5T4W',
#   'B00B7V273E'],
#  'ATJRZUXNWAWIK': ['B00BMVV3MK',
#   'B00GYCFJNQ',
#   'B00NW59IM6',
#   'B000FOI48G',
#   '9790787006',
#   'B00YCGF5T4',
#   'B0009WY5AA',
#   'B00CIUB01S',
#   'B00EZFUZA6',
#   'B00006L9LC'],
#  'ATP2UCHTR7QMZ': ['B00PYFR9PK',
#   'B01BL54RPQ',
#   'B000050FDY',
#   'B00PMQAWMI',
#   'B00FACYJ8M',
#   'B000GLRREU',
#   'B00MFMHRQ6',
#   'B00LSCERXU',
#   'B00IDEMCRE',
#   'B00M49FEQU'],
#  'ATR9J7TYR1KVL': ['B00AECS0OW',
#   'B006IB5T4W',
#   'B0189HGT2I',
#   'B00R1ZOO22',
#   'B00Q7QHGCG',
#   'B002N5MI3W',
#   'B000XQFBSM',
#   'B00BY8AGHE',
#   'B004BD9152',
#   'B00RFE2W5A'],
#  'ATVP6QJLS27EN': ['B00OXJZ73E',
#   'B01DKQAXC0',
#   'B00A4E9NA0',
#   'B00NE5Q9JO',
#   'B00OAK5J70',
#   'B01AMOTPI6',
#   'B001MP47WE',
#   'B00FC45XPQ',
#   'B0136MCSJE',
#   'B00XC8OIDC'],
#  'AU03W1V42994X': ['B00I3F4QSQ',
#   'B00D3M0CRS',
#   'B000FOI48G',
#   'B0012IT03M',
#   'B01C4QF5KM',
#   'B00TKR6MF6',
#   'B001QY8QXM',
#   'B001QY8QXM',
#   'B00M9OZRXU',
#   'B00NT0AR7E'],
#  'AU1BVXGV2KO8I': ['B0012Y0ZG2',
#   'B019NNXYJS',
#   'B00MHONF2C',
#   'B00VJZT4X4',
#   'B003CU26SY',
#   'B00WT2O8S2',
#   'B000FEF1V4',
#   'B00L0Y4DQ2',
#   'B00EC21OIE',
#   'B00ZQED66A'],
#  'AU2JWZMFEVAH5': ['B00FRDPQ54',
#   'B017WJ3R9C',
#   'B0015S8026',
#   'B000UYIQYI',
#   'B01B57QJHY',
#   'B010DM018K',
#   'B00FP16508',
#   'B01A1DW4ZE',
#   'B011I8D6L2',
#   'B01EGAJMBC'],
#  'AU3MVNMVFSIM': ['B001W2P11S',
#   'B0006Q01OI',
#   'B0195R1FT8',
#   'B00H4C6L2I',
#   'B0050RIN98',
#   'B00SAJ65B6',
#   'B00YNSV8T2',
#   'B01D2G7PRY',
#   'B00YE5VRGI',
#   'B00FNQLX1Q'],
#  'AUKMWTDK16PAP': ['B00O3092KW',
#   'B004CA943I',
#   'B00L2KGTPC',
#   'B00FIUEIY6',
#   'B017WIFR7S',
#   'B00W2Y6TI4',
#   'B018WCT01C',
#   'B00YQTQ9I8',
#   'B00KGUD3NA',
#   'B000WZNZAA'],
#  'AUWJT1DM7SG2D': ['B00L8VWCK6',
#   'B0195R1FT8',
#   'B018WFWE1C',
#   'B000WYJTZG',
#   'B0091JMCPM',
#   'B00IY2AFHY',
#   'B00FW6JXNM',
#   'B00GW58YC8',
#   'B00LP9UFYG',
#   'B005IHT94S'],
#  'AV0O5NWF2NKDF': ['B019FOXB70',
#   'B01FWY8VF4',
#   'B000URXP6E',
#   'B01FTP9LNC',
#   'B0061RJJSK',
#   'B006IB5T4W',
#   'B00I4ZTFCM',
#   'B000LIBUBY',
#   'B00HMBN5PC',
#   'B000QU1602'],
#  'AV2MC7NNTMKTF': ['B000BKXGXW',
#   'B00DGGT790',
#   'B012B57XSS',
#   'B016ADWEOU',
#   'B001E5E9RK',
#   'B0012Y0ZG2',
#   'B00FE90M0K',
#   'B001HYO65S',
#   'B00M4KNHWM',
#   'B00Z0B4S6G'],
#  'AVC89473DX6XU': ['B000MT1GHA',
#   'B00DF48HIU',
#   'B00M1XG18E',
#   'B019VP4ZM8',
#   'B00JBV1FJE',
#   'B00C7KVUEQ',
#   'B00RN4XBNY',
#   '1620213982',
#   'B00FZMF1OI',
#   'B005IHT94S'],
#  'AVFBQDR2KRNK6': ['B01D4NRGE2',
#   'B015UELU1S',
#   'B001QY8QXM',
#   'B013ZDZLVQ',
#   'B00OZOZD2C',
#   'B001AMRQ2W',
#   'B000GZJIVQ',
#   'B0175PT3KK',
#   'B00AQXD2HO',
#   'B01BLQ5D1C'],
#  'AVIMJH2FF6QCH': ['B000YB70PS',
#   'B007K6LID0',
#   'B01DAKDW42',
#   'B0186AH6VG',
#   'B000FEGUIM',
#   'B00W259T7G',
#   'B001U1KX6O',
#   'B00W259T7G',
#   'B018SFIGXG',
#   'B000EPUQKK'],
#  'AVO5FL5T9EZSR': ['B000GW78MU',
#   'B0012Y0ZG2',
#   'B00WWP5FHO',
#   'B008I2IKAO',
#   'B001A1NJOM',
#   'B000G8LWZI',
#   'B001QY8QXM',
#   'B00182JYSS',
#   'B00JBC9TD2',
#   'B001MW1MK2'],
#  'AVQ0V2MIW2Z5K': ['B01E6NITSG',
#   'B01CO1TSSM',
#   'B0148A8B8A',
#   'B00GC4HCSG',
#   'B01016RFCS',
#   'B01DH9NS2C',
#   'B001V9FPHM',
#   'B01DFHDMS6',
#   'B00HA8JNSU',
#   'B000NQ6PJ6'],
#  'AVWSUUBWD3RK4': ['B00DHF9UVA',
#   'B00Z5VI9MK',
#   'B017J9EZDW',
#   'B01E21CEXS',
#   'B00AUXUYBW',
#   'B000R90N60',
#   'B00021KD2C',
#   'B000FOI48G',
#   'B00VF344X0',
#   'B001QY8QXM'],
#  'AWJFUVK3064HX': ['B01B9YSTXK',
#   'B019LBMXBM',
#   'B0167XBHO6',
#   'B015491IW0',
#   'B000FED5DU',
#   'B000FOI48G',
#   'B007QG7G3U',
#   'B00ZR3QA18',
#   'B001EWEP9A',
#   'B0186YCGVM'],
#  'AXM9OKKHRR4RP': ['B00112DRHY',
#   'B00LP9UFYG',
#   'B00X71KYJG',
#   'B000NY66DS',
#   'B01G6YN23U',
#   'B018EMMDOQ',
#   'B000FOI48G',
#   'B0002J3FEW',
#   'B00W259T7G',
#   'B001AJ8YGC'],
#  'AXPZI9N8HVHYO': ['B017CHORY8',
#   'B00V8ZCQ7Q',
#   '1620213982',
#   '1620213982',
#   'B01B18T01Y',
#   'B000050FDY',
#   'B013ZA7PZY',
#   'B01ESXYOZQ',
#   'B0010ZBORW',
#   'B000BJ1CGQ'],
#  'AXQ57AZLKLPCQ': ['B000GLRREU',
#   'B006WYJM8Y',
#   'B01HC6G4D6',
#   'B00ZHS2E3G',
#   'B000050FDY',
#   'B01614ADHI',
#   'B00021DJ32',
#   'B00CUG25FU',
#   'B004A7NXG2',
#   'B006YGCSKO'],
#  'AXQS1B3WVRHQV': ['B000068PBQ',
#   'B00CUG25FU',
#   'B0052YPJ7S',
#   'B000FOI48G',
#   'B001QY8QXM',
#   '1620213982',
#   'B00NZDY8W0',
#   'B00CR6X0IY',
#   'B0177HMW8Q',
#   'B014HE3EUM'],
#  'AXS7NH3GDN7EE': ['B018IWJAHK',
#   'B0009MFZAE',
#   'B01EGH00J8',
#   '1620213982',
#   'B015ZOWER2',
#   'B01CRSWZAU',
#   'B00YAFS3F0',
#   'B00126LYJM',
#   'B000WNAB2M',
#   'B000URXP6E'],
#  'AY4F95T0JSTZ2': ['B00Y7YQCQQ',
#   'B001ERK70G',
#   'B00KGV1NK4',
#   'B002FRIYW2',
#   'B00AJECD2A',
#   'B00WWP5FHO',
#   'B01B6YTFRC',
#   'B0009ET47W',
#   'B001DRMGQA',
#   'B0006NXAHQ'],
#  'AYG63OK9TNBNP': ['B00XZA42TW',
#   'B000URXP6E',
#   'B01BV7MUZ8',
#   'B006GESCPY',
#   'B00E4DF6J4',
#   'B000FEF1V4',
#   'B01EK58IXG',
#   'B01GKK7HF4',
#   'B000067E30',
#   'B01DW533VM'],
#  'AZE64W03EUJA4': ['B0148ICKWU',
#   'B01GGPKJ2Q',
#   'B01FH2469Q',
#   'B0070Z6Y2G',
#   'B00S4ABX2W',
#   'B001QY8QXM',
#   'B00W259T7G',
#   'B01CDEJ1H8',
#   'B00A6IKZBU',
#   'B00DNK6NHS'],
#  'AZECTAHZICNW5': ['B00L0JYAZG',
#   'B00D3M0CRS',
#   'B002OXSKF8',
#   'B01FLJROJ4',
#   'B00KO9G48E',
#   'B00JBC9TD2',
#   'B010SV3L3I',
#   'B01FE87C4Y',
#   'B01GCL654K',
#   'B005ROU5U4'],
#  'AZEGZXCFTLSQB': ['B00W3I044Y',
#   'B00MPANY2O',
#   'B00112DRHY',
#   'B005GMY84Q',
#   'B00H3QPULS',
#   'B0000ZHGZ2',
#   'B00BMVV3MK',
#   'B0012Y0ZG2',
#   'B000VUXCGI',
#   'B01AMECL5U'],
#  'AZEKC7DEXXJD7': ['B005ROU5U4',
#   'B0001HYJW2',
#   'B019DWCJDG',
#   '1620213982',
#   'B006D8GE4E',
#   'B00D8FUHFC',
#   'B000FOI48G',
#   'B00D3CV22C',
#   'B000PARERW',
#   'B01GGPKJ2Q'],
#  'AZFGSCB0S59LQ': ['B000OV40LA',
#   'B00IBOM2Z8',
#   'B00NNLKABW',
#   'B01DVGC6C4',
#   'B011JG1K3E',
#   'B0175PT3KK',
#   'B010OPLKMM',
#   'B01G37STL0',
#   'B00HFOYU82',
#   'B00JGZNL4W'],
#  'AZHS42HV4FKKA': ['B0159ZECGI',
#   'B015RMGH6G',
#   'B01E81N2CY',
#   'B01D1VBI78',
#   'B00A2WF0D8',
#   'B000FOI48G',
#   'B000WYJTZG',
#   'B0001TMDF0',
#   'B01FTP9LNC',
#   'B00MGK9Z8U']}

# %% [markdown]
# ## 結果評估

# %%
def evaluate(ratings_testings_by_user={}, ratings_by_user={}, method=None):
    '''
    * ratings_testings_by_user: dict 真實被購買的商品資料（2018-09-01 以後資料）
    * ratings_by_user: dict 利用訓練資料學習的推薦商品
    * method: str
    * score: float
    '''
    total = 0
    for d in ratings_testings_by_user:
        if d in ratings_by_user:
            total += len(set(ratings_by_user[d]) & set(ratings_testings_by_user[d]))

    score = total / len(ratings_testings)
    return score

evaluate(ratings_testings_by_user, ratings_by_user)
# Out:
# 0.010169491525423728
